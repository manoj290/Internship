# %%
import pandas as pd
import selenium
from selenium import webdriver

# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
driver.get("https://www.naukri.com/")

# %%
searchJob=driver.find_element_by_id("qsb-keyword-sugg")
searchJob.send_keys("Data Analyst")
search_loc=driver.find_element_by_id("qsb-location-sugg")
search_loc.send_keys("qsb-location-sugg")
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   """Entry point for launching an IPython kernel.
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
search_btn=driver.find_element_by_xpath("//div[@class='search-btn']/button")
search_btn.click()
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   """Entry point for launching an IPython kernel.

# %%
driver.get("https://www.naukri.com/data-analyst-jobs-in-bangalore-bengaluru?k=data%20analyst&l=bangalore%2Fbengaluru")

# %%
job_title=[]
titletag=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
titletag

job_title.append([i.text for i in titletag])

job_title
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# [['Jr. Data Analyst/ Jr. Data Scientist',
#   'Data Analyst',
#   'Data Analyst',
#   'Data Analyst - Marketing',
#   'Hiring Business Data Analyst +ETL- Tech Mahindra, Bangalore',
#   'Data & Performance R&D and Innovation Data Analyst',
#   'Data & Performance Strategy & Insight Data Analyst',
#   'Data Analyst',
#   'Professional 1 Data Analyst',
#   'Manager - Data Analyst',
#   'Senior Data Analyst- Collection(Fintech)',
#   'Senior Data Analyst',
#   'Data Analyst/ ETL Analyst (Computers Degree Preferred)',
#   'Data Analyst',
#   'Assistant Manager - Data Analyst',
#   'Senior Data Analyst',
#   'Senior Data Analyst',
#   'Senior Data Analyst',
#   'Senior Data Analyst',
#   'Data Analyst - Python/SQL']]

# %%
exp=[]
exptag=driver.find_elements_by_xpath("//span[@class='ellipsis fleft fs12 lh16 ']")
exp.append([i.text for i in exptag])
exp
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# [['0-5 Yrs',
#   'Not disclosed',
#   'Hyderabad/Secunderabad, Bangalore/Bengaluru, Mumbai (All Areas)',
#   '2-5 Yrs',
#   'Not disclosed',
#   'Bangalore/Bengaluru',
#   '7-10 Yrs',
#   'Not disclosed',
#   'Bangalore/Bengaluru',
#   '0-2 Yrs',
#   'Not disclosed',
#   'Bangalore/Bengaluru',
#   '6-10 Yrs',
#   'Not disclosed',
#   'Bangalore/Bengaluru',
#   '3-6 Yrs',
#   'Not disclosed',
#   'Bangalore/Bengaluru',
#   '3-6 Yrs',
#   'Not disclosed',
#   'Bangalore/Bengaluru',
#   '5-10 Yrs',
#   'Not disclosed',
#   'Bangalore/Bengaluru',
#   '2-5 Yrs',
#   'Not disclosed',
#   'Bangalore/Bengaluru',
#   '5-10 Yrs',
#   'Not disclosed',
#   'Bangalore/Bengaluru',
#   '3-8 Yrs',
#   'Not disclosed',
#   'Bangalore/Bengaluru',
#   '8-13 Yrs',
#   'Not disclosed',
#   'Bangalore/Bengaluru',
# ...

# %%
exps=exp[0][::3]
exps
# Out:
# ['0-5 Yrs',
#  '2-5 Yrs',
#  '7-10 Yrs',
#  '0-2 Yrs',
#  '6-10 Yrs',
#  '3-6 Yrs',
#  '3-6 Yrs',
#  '5-10 Yrs',
#  '2-5 Yrs',
#  '5-10 Yrs',
#  '3-8 Yrs',
#  '8-13 Yrs',
#  '0-1 Yrs',
#  '0-2 Yrs',
#  '3-8 Yrs',
#  '4-7 Yrs',
#  '5-8 Yrs',
#  '2-5 Yrs',
#  '5-10 Yrs',
#  '3-5 Yrs']

# %%
loc=exp[0][2::3]
loc
# Out:
# ['Hyderabad/Secunderabad, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru(2nd Phase JP Nagar)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
company_name=[]
comtags=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
company_name.append([i.text for i in comtags])
company_name
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# [['Sejal Consulting Hub',
#   'Capgemini',
#   'GlaxoSmithKline Pharmaceuticals Limited',
#   'Razorpay',
#   'Tech Mahindra',
#   'Schneider Electric',
#   'Schneider Electric',
#   'GlaxoSmithKline Pharmaceuticals Limited',
#   'DXC Technology',
#   'Genpact',
#   'FINNOVATION TECH SOLUTIONS PRIVATE LIMITED',
#   'Cerner Corporation',
#   'Clarivate Analytics',
#   'Snaphunt',
#   'Genpact',
#   'Vmware',
#   'Liventus Technology Services',
#   'Cerner Corporation',
#   'Jupiter.money',
#   'Affine']]

# %%
DataAnalystdf=pd.DataFrame()
DataAnalystdf["Job Title"]=job_title[0][:10]
DataAnalystdf['Job Location']=loc[:10]
DataAnalystdf["Experience"]=exps[:10]
DataAnalystdf["Company Name"]=company_name[0][:10]
DataAnalystdf
# Out:
#                                            Job Title  \
# 0               Jr. Data Analyst/ Jr. Data Scientist
# 1                                       Data Analyst
# 2                                       Data Analyst
# 3                           Data Analyst - Marketing
# 4  Hiring Business Data Analyst +ETL- Tech Mahind...
# 5  Data & Performance R&D and Innovation Data Ana...
# 6  Data & Performance Strategy & Insight Data Ana...
# 7                                       Data Analyst
# 8                        Professional 1 Data Analyst
# 9                             Manager - Data Analyst
#
#                                         Job Location Experience  \
# 0  Hyderabad/Secunderabad, Bangalore/Bengaluru, M...    0-5 Yrs
# 1                                Bangalore/Bengaluru    2-5 Yrs
# 2                                Bangalore/Bengaluru   7-10 Yrs
# 3                                Bangalore/Bengaluru    0-2 Yrs
# ...

# %%
driver.close()

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
driver.get("https://www.naukri.com/data-scientist-jobs-in-bangalore-bengaluru?k=data%20scientist&l=bangalore%2Fbengaluru")

# %%
job_title=[]
titletag=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")

job_title.append([i.text for i in titletag])

job_title
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# [['Lead/Senior Data Scientist (NLP)',
#   'Jr. Data Analyst/ Jr. Data Scientist',
#   'Senior Data Scientist',
#   'Senior Data Scientist',
#   'Tcs Hiring For Data Scientist (Python GCP)',
#   'Senior Data Scientist / Data Scientist',
#   'DG - Business Analyst - Data Scientist',
#   'Senior Manager - Data Scientist',
#   'Senior Data Scientist - Immediate Joiner Preferred',
#   'Lead Consultant - Data Scientist',
#   'Sr. Data Scientist / Data Scientist For Bangalore Location',
#   'Lead Data Scientist - Machine Learning/ Data Mining',
#   'Data Scientist',
#   'Data Scientist',
#   'Data Scientist/ Data Science Ph.D. Fellowship',
#   'Urgent opening For Data Scientist',
#   'Associate Principle Data Scientist',
#   'DG - Manager - Data Scientist',
#   'Data Scientist',
# ...

# %%
com=[]
exptag=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
com.append([i.text for i in exptag])
com
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# [['Samya.AI A FRACTAL Entity',
#   'Sejal Consulting Hub',
#   'Wipro',
#   'Wipro',
#   'Tata Consultancy Services Ltd.',
#   'Superior Group',
#   'Genpact',
#   'Genpact',
#   'PlaceMinds Consulting Pvt. Ltd',
#   'Genpact',
#   'mPokket',
#   'Wrackle Technologies Pvt Ltd',
#   'Autodesk',
#   'Klub',
#   'Predictive Research',
#   'PPN Solutions Pvt Ltd.',
#   'TMF Group',
#   'Genpact',
#   'Tata Consultancy Services Ltd.',
#   'Genpact']]

# %%
loc=[]
loctag=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span")
loc.append([i.text for i in loctag])
loc
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# [['Bangalore/Bengaluru',
#   '(WFH during Covid)',
#   'Hyderabad/Secunderabad, Bangalore/Bengaluru, Mumbai (All Areas)',
#   'Pune, Bangalore/Bengaluru, Delhi / NCR',
#   'Kolkata, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)',
#   '(WFH during Covid)',
#   'Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
#   'Bangalore/Bengaluru',
#   'Bangalore/Bengaluru',
#   'Bangalore/Bengaluru',
#   'Mumbai, Pune, Bangalore/Bengaluru',
#   'Bangalore/Bengaluru',
#   'Kolkata, Bangalore/Bengaluru',
#   'Bangalore/Bengaluru',
#   'Bangalore/Bengaluru',
#   'Bangalore/Bengaluru',
#   'Bangalore/Bengaluru(JP Nagar)',
#   'Hyderabad/Secunderabad, Bangalore/Bengaluru',
#   'Bangalore/Bengaluru',
#   'Bangalore/Bengaluru',
# ...

# %%
DataScientistdf=pd.DataFrame()
DataScientistdf['Job Title']=job_title[0][:10]
DataScientistdf['Company_name']=com[0][:10]
DataScientistdf['Location']=loc[0][:10]
DataScientistdf
# Out:
#                                            Job Title  \
# 0                   Lead/Senior Data Scientist (NLP)
# 1               Jr. Data Analyst/ Jr. Data Scientist
# 2                              Senior Data Scientist
# 3                              Senior Data Scientist
# 4         Tcs Hiring For Data Scientist (Python GCP)
# 5             Senior Data Scientist / Data Scientist
# 6             DG - Business Analyst - Data Scientist
# 7                    Senior Manager - Data Scientist
# 8  Senior Data Scientist - Immediate Joiner Prefe...
# 9                   Lead Consultant - Data Scientist
#
#                      Company_name  \
# 0       Samya.AI A FRACTAL Entity
# 1            Sejal Consulting Hub
# 2                           Wipro
# 3                           Wipro
# 4  Tata Consultancy Services Ltd.
# 5                  Superior Group
# 6                         Genpact
# 7                         Genpact
# 8  PlaceMinds Consulting Pvt. Ltd
# ...

# %%
driver.close()

# %% [markdown]
# ## Q3

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
driver.get("https://www.naukri.com/data-scientist-jobs?k=data%20scientist&cityTypeGid=9508&ctcFilter=3to6")

# %%
job_title=[]
titletag=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
titletag

job_title.append([i.text for i in titletag])

job_title
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# [['Data Scientist/ Senior Data Scientist',
#   'NTT DATA_ Hiring For BIG DATA ,DATA Scientist, Devops',
#   'Hiring For Data Scientist',
#   'Hiring For Data Analyst / Data Scientist',
#   'Data Analyst / Data Scientist / Business Analytics / Fresher - MNC',
#   'Project Manager | Team Leader | Senior Data Scientist',
#   'Data Scientist',
#   'Data Scientist',
#   'Urgent Hiring For Data Scientist | Work From Office',
#   'Data Scientist',
#   'Data Scientist',
#   'Data Scientist',
#   'Data Scientist',
#   'Data Scientist',
#   'Data Scientist Internship',
#   'Data Analyst/Scientist Big Data, Statistical Techniques',
#   'Associate Data Scientist',
#   'Data Scientist',
#   'Job Opportunity || Data Scientist || HCL Technologies',
#   'Data Scientist - Insurance']]

# %%
job_loc=[]
loctag=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span")
loctag

job_loc.append([i.text for i in loctag])

job_loc
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# [['Noida',
#   'Noida, Kolkata, Hyderabad/Secunderabad, Ahmedabad, Chennai, Coimbatore, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)',
#   '(WFH during Covid)',
#   'Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)',
#   '(WFH during Covid)',
#   'Noida(Sector-59 Noida)',
#   'Noida, Ghaziabad, Delhi / NCR',
#   'Remote',
#   'Gurgaon/Gurugram, Chennai',
#   'New Delhi',
#   'Noida(Sector-59 Noida)',
#   'Gurgaon/Gurugram',
#   'Mumbai, Hyderabad/Secunderabad, Pune, Lucknow, Chennai, Delhi / NCR, Kerela, Goa',
#   'Gurgaon/Gurugram',
#   'Gurgaon/Gurugram',
#   'Gurgaon/Gurugram, Bangalore/Bengaluru',
#   'New Delhi',
#   'Gurgaon/Gurugram',
#   'Noida',
#   'Noida(Sector-126 Noida)',
#   'Delhi / NCR',
#   'Noida, Gurgaon/Gurugram']]

# %%
company=[]
comtag=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
comtag

company.append([i.text for i in comtag])

company
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# [['Newgen Software Technologies',
#   'NTT Data Business Solutions Pvt Ltd',
#   'Tata Consultancy Services Ltd.',
#   'Careerera',
#   'GABA Consultancy services',
#   'Tidyquant (OPC) Private Limited',
#   'Teleperformance',
#   'The Boston Consulting Group (India) Pvt Limited',
#   'Careerera',
#   'ApplyBoard',
#   'AVE-Promagne',
#   'Whizhack Technologies pvt ltd',
#   'One Mobikwik Systems Private Limited',
#   'Hexagon Geosystems Services India P.Ltd.',
#   'iHackers Inc',
#   'The Search House (A Div of JSD Search House Pvt. L td.)',
#   'Right Step Consulting',
#   'MoMagic Technologies',
#   'HCL Technologies',
#   'Huquo Consulting Pvt. Ltd']]

# %%
exp=[]
exptag=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']/span")
exptag

exp.append([i.text for i in exptag])

exp
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# [['2-5 Yrs',
#   '3-8 Yrs',
#   '4-9 Yrs',
#   '1-3 Yrs',
#   '0-0 Yrs',
#   '1-5 Yrs',
#   '4-9 Yrs',
#   '2-5 Yrs',
#   '2-7 Yrs',
#   '3-7 Yrs',
#   '1-6 Yrs',
#   '2-5 Yrs',
#   '2-5 Yrs',
#   '6-11 Yrs',
#   '0-1 Yrs',
#   '2-7 Yrs',
#   '3-6 Yrs',
#   '4-6 Yrs',
#   '4-7 Yrs',
#   '2-7 Yrs']]

# %%
DataScientistFiltereddf=pd.DataFrame()
DataScientistFiltereddf['Job Title']=job_title[0][:10]
DataScientistFiltereddf['Job Location']=job_loc[0][:10]
DataScientistFiltereddf['Company Name']=company[0][:10]
DataScientistFiltereddf['Experience']=exp[0][:10]
DataScientistFiltereddf
# Out:
#                                            Job Title  \
# 0              Data Scientist/ Senior Data Scientist
# 1  NTT DATA_ Hiring For BIG DATA ,DATA Scientist,...
# 2                          Hiring For Data Scientist
# 3           Hiring For Data Analyst / Data Scientist
# 4  Data Analyst / Data Scientist / Business Analy...
# 5  Project Manager | Team Leader | Senior Data Sc...
# 6                                     Data Scientist
# 7                                     Data Scientist
# 8  Urgent Hiring For Data Scientist | Work From O...
# 9                                     Data Scientist
#
#                                         Job Location  \
# 0                                              Noida
# 1  Noida, Kolkata, Hyderabad/Secunderabad, Ahmeda...
# 2                                 (WFH during Covid)
# 3  Hyderabad/Secunderabad, Pune, Chennai, Bangalo...
# 4                                 (WFH during Covid)
# 5                             Noida(Sector-59 Noida)
# ...

# %%
driver.close()

# %% [markdown]
# ## Q.4

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
driver.get("https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off")

# %%
brand=[]
brandtag=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
brand.extend([i.text for i in brandtag])
brand
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['ROYAL SON',
#  'ROZZETTA CRAFT',
#  'SRPM',
#  'Fastrack',
#  'Elligator',
#  'PIRASO',
#  'PIRASO',
#  'ROYAL SON',
#  'kingsunglasses',
#  'SHAAH COLLECTIONS',
#  'New Specs',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'PHENOMENAL',
#  'PIRASO',
#  'Rich Club',
#  'PIRASO',
#  'SHAAH COLLECTIONS',
#  'kingsunglasses',
#  'Rich Club',
#  'Fastrack',
#  'New Specs',
#  'ROZZETTA CRAFT',
#  'HH POLARIZED',
#  'kingsunglasses',
#  'ROYAL SON',
#  'SUNBEE',
#  'ROYAL SON',
#  'PIRASO',
#  'PHENOMENAL',
#  'Rich Club',
#  'AISLIN',
#  'hipe',
#  'kingsunglasses',
#  'ROYAL SON',
#  'ROADWAY',
#  'Rich Club',
#  'PIRASO',
#  'Elligator',
#  'ROADWAY']

# %%
description=[]
desctag=driver.find_elements_by_xpath("//a[@class='IRpwTa']")
description.extend([i.text for i in desctag])
description
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['Polarized, UV Protection Round Sunglasses (53)',
#  'UV Protection Spectacle Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (56)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (54)',
#  'Polarized, UV Protection Aviator Sunglasses (58)',
#  'Mirrored, UV Protection Wayfarer Sunglasses (53)',
#  'UV Protection, Polarized, Mirrored Rectangular Sunglass...',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'Polarized, UV Protection Round Sunglasses (53)',
#  'UV Protection, Gradient Rectangular Sunglasses (Free Si...',
#  'UV Protection Retro Square Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (32)',
# ...

# %%
price=[]
ptag=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
price.extend([i.text for i in ptag])
price
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['₹664',
#  '₹499',
#  '₹188',
#  '₹639',
#  '₹248',
#  '₹187',
#  '₹200',
#  '₹759',
#  '₹274',
#  '₹170',
#  '₹259',
#  '₹664',
#  '₹383',
#  '₹319',
#  '₹187',
#  '₹383',
#  '₹187',
#  '₹181',
#  '₹187',
#  '₹383',
#  '₹759',
#  '₹255',
#  '₹474',
#  '₹225',
#  '₹189',
#  '₹359',
#  '₹271',
#  '₹664',
#  '₹200',
#  '₹299',
#  '₹165',
#  '₹434',
#  '₹189',
#  '₹259',
#  '₹449',
#  '₹381',
#  '₹164',
#  '₹299',
#  '₹291',
#  '₹296']

# %%
off=[]
offtag=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span")
off.extend([i.text for i in offtag])
off
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# ['66% off',
#  '75% off',
#  '85% off',
#  '20% off',
#  '90% off',
#  '88% off',
#  '87% off',
#  '62% off',
#  '86% off',
#  '89% off',
#  '87% off',
#  '66% off',
#  '80% off',
#  '84% off',
#  '88% off',
#  '61% off',
#  '88% off',
#  '81% off',
#  '84% off',
#  '61% off',
#  '15% off',
#  '84% off',
#  '78% off',
#  '77% off',
#  '82% off',
#  '76% off',
#  '84% off',
#  '66% off',
#  '87% off',
#  '85% off',
#  '66% off',
#  '71% off',
#  '87% off',
#  '87% off',
#  '70% off',
#  '80% off',
#  '67% off',
#  '88% off',
#  '85% off',
#  '77% off']

# %%
driver.get("https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off&page=2")

# %%
brandtag=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
brand.extend([i.text for i in brandtag])
brand
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """Entry point for launching an IPython kernel.
# ['ROYAL SON',
#  'ROZZETTA CRAFT',
#  'SRPM',
#  'Fastrack',
#  'Elligator',
#  'PIRASO',
#  'PIRASO',
#  'ROYAL SON',
#  'kingsunglasses',
#  'SHAAH COLLECTIONS',
#  'New Specs',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'PHENOMENAL',
#  'PIRASO',
#  'Rich Club',
#  'PIRASO',
#  'SHAAH COLLECTIONS',
#  'kingsunglasses',
#  'Rich Club',
#  'Fastrack',
#  'New Specs',
#  'ROZZETTA CRAFT',
#  'HH POLARIZED',
#  'kingsunglasses',
#  'ROYAL SON',
#  'SUNBEE',
#  'ROYAL SON',
#  'PIRASO',
#  'PHENOMENAL',
#  'Rich Club',
#  'AISLIN',
#  'hipe',
#  'kingsunglasses',
#  'ROYAL SON',
#  'ROADWAY',
#  'Rich Club',
#  'PIRASO',
#  'Elligator',
#  'ROADWAY',
#  'Lee Topper',
#  'NuVew',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'Elligator',
#  'agera',
# ...

# %%
desctag=driver.find_elements_by_xpath("//a[@class='IRpwTa']")
description.extend([i.text for i in desctag])
description
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """Entry point for launching an IPython kernel.
# ['Polarized, UV Protection Round Sunglasses (53)',
#  'UV Protection Spectacle Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (56)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (54)',
#  'Polarized, UV Protection Aviator Sunglasses (58)',
#  'Mirrored, UV Protection Wayfarer Sunglasses (53)',
#  'UV Protection, Polarized, Mirrored Rectangular Sunglass...',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'Polarized, UV Protection Round Sunglasses (53)',
#  'UV Protection, Gradient Rectangular Sunglasses (Free Si...',
#  'UV Protection Retro Square Sunglasses (Free Size)',
# ...

# %%
ptag=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
price.extend([i.text for i in ptag])
price
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """Entry point for launching an IPython kernel.
# ['₹664',
#  '₹499',
#  '₹188',
#  '₹639',
#  '₹248',
#  '₹187',
#  '₹200',
#  '₹759',
#  '₹274',
#  '₹170',
#  '₹259',
#  '₹664',
#  '₹383',
#  '₹319',
#  '₹187',
#  '₹383',
#  '₹187',
#  '₹181',
#  '₹187',
#  '₹383',
#  '₹759',
#  '₹255',
#  '₹474',
#  '₹225',
#  '₹189',
#  '₹359',
#  '₹271',
#  '₹664',
#  '₹200',
#  '₹299',
#  '₹165',
#  '₹434',
#  '₹189',
#  '₹259',
#  '₹449',
#  '₹381',
#  '₹164',
#  '₹299',
#  '₹291',
#  '₹296',
#  '₹276',
#  '₹240',
#  '₹426',
#  '₹664',
#  '₹239',
#  '₹196',
#  '₹322',
#  '₹759',
#  '₹299',
#  '₹276',
#  '₹187',
#  '₹264',
#  '₹383',
#  '₹299',
#  '₹299',
#  '₹664',
#  '₹375',
#  '₹299',
#  '₹185',
#  '₹269',
#  '₹194',
#  '₹359',
#  '₹399',
#  '₹272',
#  '₹299',
#  '₹619',
#  '₹729',
#  '₹349',
# ...

# %%
offtag=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span")
off.extend([i.text for i in offtag])
off
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """Entry point for launching an IPython kernel.
# ['66% off',
#  '75% off',
#  '85% off',
#  '20% off',
#  '90% off',
#  '88% off',
#  '87% off',
#  '62% off',
#  '86% off',
#  '89% off',
#  '87% off',
#  '66% off',
#  '80% off',
#  '84% off',
#  '88% off',
#  '61% off',
#  '88% off',
#  '81% off',
#  '84% off',
#  '61% off',
#  '15% off',
#  '84% off',
#  '78% off',
#  '77% off',
#  '82% off',
#  '76% off',
#  '84% off',
#  '66% off',
#  '87% off',
#  '85% off',
#  '66% off',
#  '71% off',
#  '87% off',
#  '87% off',
#  '70% off',
#  '80% off',
#  '67% off',
#  '88% off',
#  '85% off',
#  '77% off',
#  '88% off',
#  '69% off',
#  '80% off',
#  '66% off',
#  '88% off',
#  '82% off',
#  '87% off',
#  '62% off',
#  '88% off',
#  '83% off',
#  '88% off',
#  '86% off',
#  '61% off',
#  '85% off',
# ...

# %%
driver.get("https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off&page=3")

# %%
brandtag=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
brand.extend([i.text for i in brandtag])
brand
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """Entry point for launching an IPython kernel.
# ['ROYAL SON',
#  'ROZZETTA CRAFT',
#  'SRPM',
#  'Fastrack',
#  'Elligator',
#  'PIRASO',
#  'PIRASO',
#  'ROYAL SON',
#  'kingsunglasses',
#  'SHAAH COLLECTIONS',
#  'New Specs',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'PHENOMENAL',
#  'PIRASO',
#  'Rich Club',
#  'PIRASO',
#  'SHAAH COLLECTIONS',
#  'kingsunglasses',
#  'Rich Club',
#  'Fastrack',
#  'New Specs',
#  'ROZZETTA CRAFT',
#  'HH POLARIZED',
#  'kingsunglasses',
#  'ROYAL SON',
#  'SUNBEE',
#  'ROYAL SON',
#  'PIRASO',
#  'PHENOMENAL',
#  'Rich Club',
#  'AISLIN',
#  'hipe',
#  'kingsunglasses',
#  'ROYAL SON',
#  'ROADWAY',
#  'Rich Club',
#  'PIRASO',
#  'Elligator',
#  'ROADWAY',
#  'Lee Topper',
#  'NuVew',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'Elligator',
#  'agera',
# ...

# %%
desctag=driver.find_elements_by_xpath("//a[@class='IRpwTa']")
description.extend([i.text for i in desctag])
description
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """Entry point for launching an IPython kernel.
# ['Polarized, UV Protection Round Sunglasses (53)',
#  'UV Protection Spectacle Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (56)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (54)',
#  'Polarized, UV Protection Aviator Sunglasses (58)',
#  'Mirrored, UV Protection Wayfarer Sunglasses (53)',
#  'UV Protection, Polarized, Mirrored Rectangular Sunglass...',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'Polarized, UV Protection Round Sunglasses (53)',
#  'UV Protection, Gradient Rectangular Sunglasses (Free Si...',
#  'UV Protection Retro Square Sunglasses (Free Size)',
# ...

# %%
ptag=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
price.extend([i.text for i in ptag])
price
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """Entry point for launching an IPython kernel.
# ['₹664',
#  '₹499',
#  '₹188',
#  '₹639',
#  '₹248',
#  '₹187',
#  '₹200',
#  '₹759',
#  '₹274',
#  '₹170',
#  '₹259',
#  '₹664',
#  '₹383',
#  '₹319',
#  '₹187',
#  '₹383',
#  '₹187',
#  '₹181',
#  '₹187',
#  '₹383',
#  '₹759',
#  '₹255',
#  '₹474',
#  '₹225',
#  '₹189',
#  '₹359',
#  '₹271',
#  '₹664',
#  '₹200',
#  '₹299',
#  '₹165',
#  '₹434',
#  '₹189',
#  '₹259',
#  '₹449',
#  '₹381',
#  '₹164',
#  '₹299',
#  '₹291',
#  '₹296',
#  '₹276',
#  '₹240',
#  '₹426',
#  '₹664',
#  '₹239',
#  '₹196',
#  '₹322',
#  '₹759',
#  '₹299',
#  '₹276',
#  '₹187',
#  '₹264',
#  '₹383',
#  '₹299',
#  '₹299',
#  '₹664',
#  '₹375',
#  '₹299',
#  '₹185',
#  '₹269',
#  '₹194',
#  '₹359',
#  '₹399',
#  '₹272',
#  '₹299',
#  '₹619',
#  '₹729',
#  '₹349',
# ...

# %%
offtag=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span")
off.extend([i.text for i in offtag])
off
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """Entry point for launching an IPython kernel.
# ['66% off',
#  '75% off',
#  '85% off',
#  '20% off',
#  '90% off',
#  '88% off',
#  '87% off',
#  '62% off',
#  '86% off',
#  '89% off',
#  '87% off',
#  '66% off',
#  '80% off',
#  '84% off',
#  '88% off',
#  '61% off',
#  '88% off',
#  '81% off',
#  '84% off',
#  '61% off',
#  '15% off',
#  '84% off',
#  '78% off',
#  '77% off',
#  '82% off',
#  '76% off',
#  '84% off',
#  '66% off',
#  '87% off',
#  '85% off',
#  '66% off',
#  '71% off',
#  '87% off',
#  '87% off',
#  '70% off',
#  '80% off',
#  '67% off',
#  '88% off',
#  '85% off',
#  '77% off',
#  '88% off',
#  '69% off',
#  '80% off',
#  '66% off',
#  '88% off',
#  '82% off',
#  '87% off',
#  '62% off',
#  '88% off',
#  '83% off',
#  '88% off',
#  '86% off',
#  '61% off',
#  '85% off',
# ...

# %%
Sunglasses=pd.DataFrame()
Sunglasses['Brand']=brand[:100]
Sunglasses['Product Description']=description[:100]
Sunglasses['Price']=price[:100]
Sunglasses["Off"]=off[:100]
Sunglasses
# Out:
#                 Brand                                Product Description  \
# 0           ROYAL SON     Polarized, UV Protection Round Sunglasses (53)
# 1      ROZZETTA CRAFT     UV Protection Spectacle Sunglasses (Free Size)
# 2                SRPM             UV Protection Wayfarer Sunglasses (56)
# 3            Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# 4           Elligator                UV Protection Round Sunglasses (54)
# 5              PIRASO              UV Protection Aviator Sunglasses (54)
# 6              PIRASO              UV Protection Aviator Sunglasses (54)
# 7           ROYAL SON   Polarized, UV Protection Aviator Sunglasses (58)
# 8      kingsunglasses   Mirrored, UV Protection Wayfarer Sunglasses (53)
# 9   SHAAH COLLECTIONS  UV Protection, Polarized, Mirrored Rectangular...
# 10          New Specs   UV Protection Rectangular Sunglasses (Free Size)
# 11          ROYAL SON     Polarized, UV Protection Round Sunglasses (53)
# ...

# %%
driver.close()

# %% [markdown]
# ## Q 5

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART")

# %%
rt=[]
rttag=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rt.extend([i.text for i in rttag])
rt
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['5', '5', '5', '5', '5', '5', '5', '5', '4', '5']

# %%
review_sum=[]
reviewtag=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_sum.extend([i.text for i in reviewtag])
review_sum
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['Brilliant',
#  'Simply awesome',
#  'Perfect product!',
#  'Best in the market!',
#  'Worth every penny',
#  'Fabulous!',
#  'Great product',
#  'Worth every penny',
#  'Good choice',
#  'Highly recommended']

# %%
review_fsum=[]
freviewtag=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
review_fsum.extend([i.text for i in freviewtag])
review_fsum
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['The Best Phone for the Money\n\nThe iPhone 11 offers superb cameras, a more durable design and excellent battery life for an affordable price.\n\nCompelling ultra-wide camera\nNew Night mode is excellent\nLong battery life',
#  'Really satisfied with the Product I received... It’s totally genuine and the packaging was also really good so if ur planning to buy just go for it.',
#  'Amazing phone with great cameras and better battery which gives you the best performance. I just love the camera .',
# ...

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=2")

# %%
rttag=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rt.extend([i.text for i in rttag])
rt

reviewtag=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_sum.extend([i.text for i in reviewtag])
review_sum

freviewtag=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
review_fsum.extend([i.text for i in freviewtag])
review_fsum
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """Entry point for launching an IPython kernel.
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   if __name__ == '__main__':
# ['The Best Phone for the Money\n\nThe iPhone 11 offers superb cameras, a more durable design and excellent battery life for an affordable price.\n\nCompelling ultra-wide camera\nNew Night mode is excellent\nLong battery life',
# ...

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=3")

# %%
rttag=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rt.extend([i.text for i in rttag])
rt

reviewtag=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_sum.extend([i.text for i in reviewtag])
review_sum

freviewtag=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
review_fsum.extend([i.text for i in freviewtag])
review_fsum
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """Entry point for launching an IPython kernel.
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   """
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   if __name__ == '__main__':
# ['The Best Phone for the Money\n\nThe iPhone 11 offers superb cameras, a more durable design and excellent battery life for an affordable price.\n\nCompelling ultra-wide camera\nNew Night mode is excellent\nLong battery life',
# ...

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=4")

rttag=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rt.extend([i.text for i in rttag])
rt

reviewtag=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_sum.extend([i.text for i in reviewtag])
review_sum

freviewtag=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
review_fsum.extend([i.text for i in freviewtag])
review_fsum
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   import sys
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   # This is added back by InteractiveShellApp.init_path()
# ['The Best Phone for the Money\n\nThe iPhone 11 offers superb cameras, a more durable design and excellent battery life for an affordable price.\n\nCompelling ultra-wide camera\nNew Night mode is excellent\nLong battery life',
# ...

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=5")

rttag=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rt.extend([i.text for i in rttag])
rt

reviewtag=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_sum.extend([i.text for i in reviewtag])
review_sum

freviewtag=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
review_fsum.extend([i.text for i in freviewtag])
review_fsum
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   import sys
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   # This is added back by InteractiveShellApp.init_path()
# ['The Best Phone for the Money\n\nThe iPhone 11 offers superb cameras, a more durable design and excellent battery life for an affordable price.\n\nCompelling ultra-wide camera\nNew Night mode is excellent\nLong battery life',
# ...

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=6")

rttag=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rt.extend([i.text for i in rttag])
rt

reviewtag=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_sum.extend([i.text for i in reviewtag])
review_sum

freviewtag=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
review_fsum.extend([i.text for i in freviewtag])
review_fsum
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   import sys
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   # This is added back by InteractiveShellApp.init_path()
# ['The Best Phone for the Money\n\nThe iPhone 11 offers superb cameras, a more durable design and excellent battery life for an affordable price.\n\nCompelling ultra-wide camera\nNew Night mode is excellent\nLong battery life',
# ...

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=7")

rttag=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rt.extend([i.text for i in rttag])
rt

reviewtag=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_sum.extend([i.text for i in reviewtag])
review_sum

freviewtag=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
review_fsum.extend([i.text for i in freviewtag])
review_fsum
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   import sys
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   # This is added back by InteractiveShellApp.init_path()
# ['The Best Phone for the Money\n\nThe iPhone 11 offers superb cameras, a more durable design and excellent battery life for an affordable price.\n\nCompelling ultra-wide camera\nNew Night mode is excellent\nLong battery life',
# ...

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=8")

rttag=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rt.extend([i.text for i in rttag])
rt

reviewtag=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_sum.extend([i.text for i in reviewtag])
review_sum

freviewtag=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
review_fsum.extend([i.text for i in freviewtag])
review_fsum
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   import sys
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   # This is added back by InteractiveShellApp.init_path()
# ['The Best Phone for the Money\n\nThe iPhone 11 offers superb cameras, a more durable design and excellent battery life for an affordable price.\n\nCompelling ultra-wide camera\nNew Night mode is excellent\nLong battery life',
# ...

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=9")

rttag=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rt.extend([i.text for i in rttag])
rt

reviewtag=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_sum.extend([i.text for i in reviewtag])
review_sum

freviewtag=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
review_fsum.extend([i.text for i in freviewtag])
review_fsum
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   import sys
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   # This is added back by InteractiveShellApp.init_path()
# ['The Best Phone for the Money\n\nThe iPhone 11 offers superb cameras, a more durable design and excellent battery life for an affordable price.\n\nCompelling ultra-wide camera\nNew Night mode is excellent\nLong battery life',
# ...

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=10")

rttag=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rt.extend([i.text for i in rttag])
rt

reviewtag=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_sum.extend([i.text for i in reviewtag])
review_sum

freviewtag=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
review_fsum.extend([i.text for i in freviewtag])
review_fsum
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   import sys
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   # This is added back by InteractiveShellApp.init_path()
# ['The Best Phone for the Money\n\nThe iPhone 11 offers superb cameras, a more durable design and excellent battery life for an affordable price.\n\nCompelling ultra-wide camera\nNew Night mode is excellent\nLong battery life',
# ...

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=11")

rttag=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
rt.extend([i.text for i in rttag])
rt

reviewtag=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
review_sum.extend([i.text for i in reviewtag])
review_sum

freviewtag=driver.find_elements_by_xpath("//div[@class='t-ZTKy']")
review_fsum.extend([i.text for i in freviewtag])
review_fsum
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   import sys
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   # This is added back by InteractiveShellApp.init_path()
# ['The Best Phone for the Money\n\nThe iPhone 11 offers superb cameras, a more durable design and excellent battery life for an affordable price.\n\nCompelling ultra-wide camera\nNew Night mode is excellent\nLong battery life',
# ...

# %%
df=pd.DataFrame()
df['Rating']=rt[:100]
df["Review Summary"]=review_sum[:100]
df["Review Full Description"]=review_fsum[:100]
df
# Out:
#    Rating         Review Summary  \
# 0       5              Brilliant
# 1       5         Simply awesome
# 2       5       Perfect product!
# 3       5    Best in the market!
# 4       5      Worth every penny
# 5       5              Fabulous!
# 6       5          Great product
# 7       5      Worth every penny
# 8       4            Good choice
# 9       5     Highly recommended
# 10      5     Highly recommended
# 11      5       Perfect product!
# 12      5       Perfect product!
# 13      5         Classy product
# 14      5       Perfect product!
# 15      5      Worth every penny
# 16      5     Highly recommended
# 17      5         Simply awesome
# 18      5      Worth every penny
# 19      5      Worth every penny
# 20      5               Terrific
# 21      5              Wonderful
# 22      4           Nice product
# 23      5       Perfect product!
# 24      5              Brilliant
# 25      5         Classy product
# 26      5              Must buy!
# ...

# %%
driver.close()

# %% [markdown]
# ## Q6

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
driver.get("https://www.flipkart.com/search?q=sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")

# %%
brand=[]
brandtag=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
brand.extend([i.text for i in brandtag])
brand
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['BIRDE',
#  'HRX by Hrithik Roshan',
#  'Chevit',
#  'Numenzo',
#  'Numenzo',
#  'Edoeviv',
#  'BRUTON',
#  'HRX by Hrithik Roshan',
#  'BIRDE',
#  'Magnolia',
#  'SCATCHITE',
#  'BIRDE',
#  'Shoes Bank',
#  'Chevit',
#  'ASTEROID',
#  'PUMA',
#  'URBANBOX',
#  'SPARX',
#  'BIRDE',
#  'Extoes',
#  'RapidBox',
#  'ASTEROID',
#  'D-SNEAKERZ',
#  'Shuzer68',
#  'ganpati traders',
#  'Chevit',
#  'TR',
#  'CALCADOS',
#  'SPARX',
#  'BRUTON',
#  'believe',
#  'PUMA',
#  'Rzisbo',
#  'Kraasa',
#  'Robbie jones',
#  'PUMA',
#  'flipy',
#  'CALCADOS',
#  'Chevit',
#  'BOLTAGO']

# %%
description=[]
desctag=driver.find_elements_by_xpath("//a[@class='IRpwTa']")
description.extend([i.text for i in desctag])
description
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['Sneakers For Men',
#  'sneakers Sneakers For Men',
#  'Combo Pack of 4 Casual Sneakers With Sneakers For Men',
#  'White Sneaker For Men Sneakers For Men',
#  '411 Casual Sneakers For Men',
#  "Luxury Branded Fashionable Men's Casual Walking Partywe...",
#  'Modern Trendy Shoes Sneakers For Men',
#  'Sneakers For Men',
#  'Combo Pack of 2 Casual Shoes Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers Sneakers For Men',
#  'Sneakers For Men',
#  "White Sneaker For Men's/Boy's Sneakers For Men",
#  'Unique & Perfect Collection Combo Pack of 02 Shoes for ...',
#  "Luxury Branded Fashionable Men's Casual Walking Partywe...",
#  'Puma Smash v2 SL one8 Sneakers For Men',
#  'Men White Sneakers Sneakers For Men',
#  'Sports Running Shoes Sneakers For Men',
# ...

# %%
price=[]
ptag=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
price.extend([i.text for i in ptag])
price
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['₹598',
#  '₹1,899',
#  '₹665',
#  '₹499',
#  '₹499',
#  '₹499',
#  '₹339',
#  '₹2,999',
#  '₹472',
#  '₹398',
#  '₹377',
#  '₹598',
#  '₹331',
#  '₹599',
#  '₹499',
#  '₹3,999',
#  '₹220',
#  '₹679',
#  '₹299',
#  '₹898',
#  '₹590',
#  '₹499',
#  '₹348',
#  '₹419',
#  '₹199',
#  '₹699',
#  '₹474',
#  '₹498',
#  '₹849',
#  '₹471',
#  '₹449',
#  '₹1,499',
#  '₹549',
#  '₹444',
#  '₹451',
#  '₹4,249',
#  '₹390',
#  '₹899',
#  '₹475',
#  '₹426']

# %%
off=[]
offtag=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span")
off.extend([i.text for i in offtag])
off
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['40% off',
#  '36% off',
#  '66% off',
#  '61% off',
#  '75% off',
#  '37% off',
#  '73% off',
#  '21% off',
#  '52% off',
#  '60% off',
#  '62% off',
#  '40% off',
#  '66% off',
#  '60% off',
#  '75% off',
#  '77% off',
#  '15% off',
#  '40% off',
#  '40% off',
#  '40% off',
#  '50% off',
#  '47% off',
#  '58% off',
#  '60% off',
#  '56% off',
#  '76% off',
#  '50% off',
#  '15% off',
#  '81% off',
#  '55% off',
#  '62% off',
#  '45% off',
#  '55% off',
#  '54% off',
#  '15% off',
#  '75% off',
#  '54% off',
#  '68% off',
#  '57% off']

# %%
driver.get("https://www.flipkart.com/search?q=sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2")

brandtag=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
brand.extend([i.text for i in brandtag])
brand

desctag=driver.find_elements_by_xpath("//a[@class='IRpwTa']")
description.extend([i.text for i in desctag])
description

ptag=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
price.extend([i.text for i in ptag])
price

offtag=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span")
off.extend([i.text for i in offtag])
off

# %%
driver.get("https://www.flipkart.com/search?q=sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3")

brandtag=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
brand.extend([i.text for i in brandtag])
brand

desctag=driver.find_elements_by_xpath("//a[@class='IRpwTa']")
description.extend([i.text for i in desctag])
description

ptag=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
price.extend([i.text for i in ptag])
price

offtag=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span")
off.extend([i.text for i in offtag])
off
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   import sys
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   from ipykernel import kernelapp as app
# ['40% off',
#  '36% off',
# ...

# %%
Shoes=pd.DataFrame()
Shoes['Brand']=brand[:100]
Shoes['Product Description']=description[:100]
Shoes['Price']=price[:100]
Shoes["Off"]=off[:100]
Shoes
# Out:
#                     Brand                                Product Description  \
# 0                   BIRDE                                   Sneakers For Men
# 1   HRX by Hrithik Roshan                          sneakers Sneakers For Men
# 2                  Chevit  Combo Pack of 4 Casual Sneakers With Sneakers ...
# 3                 Numenzo             White Sneaker For Men Sneakers For Men
# 4                 Numenzo                        411 Casual Sneakers For Men
# 5                 Edoeviv  Luxury Branded Fashionable Men's Casual Walkin...
# 6                  BRUTON               Modern Trendy Shoes Sneakers For Men
# 7   HRX by Hrithik Roshan                                   Sneakers For Men
# 8                   BIRDE      Combo Pack of 2 Casual Shoes Sneakers For Men
# 9                Magnolia                                   Sneakers For Men
# 10              SCATCHITE                          Sneakers Sneakers For Men
# ...

# %%
driver.close()

# %% [markdown]
# ## Q7

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
driver.get("https://www.myntra.com/shoes?f=Color%3ABlack_36454f&rf=Price%3A7149.0_14099.0_7149.0%20TO%2014099.0")

# %%
brand=[]
brandtag=driver.find_elements_by_xpath("//h3[@class='product-brand']")
brand.extend([i.text for i in brandtag])
brand
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['Nike',
#  'Puma',
#  'Skechers',
#  'Nike',
#  'Nike',
#  'Puma',
#  'ASICS',
#  'Nike',
#  'Puma',
#  'Calvin Klein',
#  'Hush Puppies',
#  'Skechers',
#  'Bugatti',
#  'Hush Puppies',
#  'Calvin Klein',
#  'Hush Puppies',
#  'Puma',
#  'Hush Puppies',
#  'Bugatti',
#  'Bugatti',
#  'Xtep',
#  'J.FONTINI',
#  'Calvin Klein',
#  'Skechers',
#  'Puma',
#  'ASICS',
#  'ASICS',
#  'Tommy Hilfiger',
#  'Saint G',
#  'Tommy Hilfiger',
#  'Saint G',
#  'Saint G',
#  'MANGO',
#  'Geox',
#  'Bugatti',
#  'Saint G',
#  'Geox',
#  'Tommy Hilfiger',
#  'Calvin Klein',
#  'fitflop',
#  'Hush Puppies',
#  'DAVINCHI',
#  'Calvin Klein',
#  'Hush Puppies',
#  'DAVINCHI',
#  'DAVINCHI',
#  'Heel & Buckle London',
#  'Saint G',
#  'ASICS',
#  'UNDER ARMOUR']

# %%
desc=[]
desctag=driver.find_elements_by_xpath("//h4[@class='product-product']")
desc.extend([i.text for i in desctag])
desc
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['Men Zoom Span 4 Running Shoes',
#  'Men Deviate Nitro Running Shoe',
#  'Men Balance Anchor Walking',
#  'Men Waffle One SE Sneakers',
#  "Men BlazerLow '77 Sneakers",
#  'Men Running Shoes',
#  'Men Running Shoes',
#  'Men FLIGHT LEGACY Sneakers',
#  'Men Electrify Nitro Running',
#  'Men Textured Leather Sneaker',
#  'Men Solid Formal Slip-Ons',
#  'Men Go Run Pure 2 Axis Running',
#  'Men Running Shoes',
#  'Men Formal Derbys',
#  'Men Solid Mid-Top Sneakers',
#  'Men Solid Leather Formal Slip-Ons',
#  'Men Magnify Nitro Running',
#  'Men Solid Leather Formal Slip-Ons',
#  'Men Textured Leather High-Top Flat Boots',
#  'Men Black Walking Shoes',
#  'Men Running Shoes',
#  'Men Solid Loafers',
#  'Men UV MONO Leather Sneakers',
#  'Men Go Run Hyper Burst Running',
# ...

# %%
price=[]
ptag=driver.find_elements_by_xpath("//div[@class='product-price']/span")
price.extend([i.text for i in ptag])

price
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['Rs. 7195',
#  'Rs. 8999Rs. 14999',
#  '(40% OFF)',
#  'Rs. 9999',
#  'Rs. 8295',
#  'Rs. 7195',
#  'Rs. 8449Rs. 12999',
#  '(35% OFF)',
#  'Rs. 7999',
#  'Rs. 7995',
#  'Rs. 7499Rs. 9999',
#  '(25% OFF)',
#  'Rs. 9999',
#  'Rs. 9999',
#  'Rs. 7499',
#  'Rs. 9999',
#  'Rs. 9999',
#  'Rs. 10599',
#  'Rs. 8999',
#  'Rs. 9099Rs. 12999',
#  '(30% OFF)',
#  'Rs. 9999',
#  'Rs. 11999',
#  'Rs. 8999',
#  'Rs. 7699',
#  'Rs. 8990',
#  'Rs. 8999',
#  'Rs. 8499',
#  'Rs. 7799Rs. 12999',
#  '(40% OFF)',
#  'Rs. 9999',
#  'Rs. 7999',
#  'Rs. 7999',
#  'Rs. 8500Rs. 10500',
#  '(Rs. 2000 OFF)',
#  'Rs. 7999',
#  'Rs. 7900Rs. 8900',
#  '(Rs. 1000 OFF)',
#  'Rs. 11900Rs. 13900',
#  '(Rs. 2000 OFF)',
#  'Rs. 7990',
#  'Rs. 8999',
#  'Rs. 9999',
#  'Rs. 9800Rs. 13900',
#  '(Rs. 4100 OFF)',
#  'Rs. 9999',
# ...

# %%
for i in price:
    if "OFF" in i:
        price.remove(i)
price
# Out:
# ['Rs. 7195',
#  'Rs. 8999Rs. 14999',
#  'Rs. 9999',
#  'Rs. 8295',
#  'Rs. 7195',
#  'Rs. 8449Rs. 12999',
#  'Rs. 7999',
#  'Rs. 7995',
#  'Rs. 7499Rs. 9999',
#  'Rs. 9999',
#  'Rs. 9999',
#  'Rs. 7499',
#  'Rs. 9999',
#  'Rs. 9999',
#  'Rs. 10599',
#  'Rs. 8999',
#  'Rs. 9099Rs. 12999',
#  'Rs. 9999',
#  'Rs. 11999',
#  'Rs. 8999',
#  'Rs. 7699',
#  'Rs. 8990',
#  'Rs. 8999',
#  'Rs. 8499',
#  'Rs. 7799Rs. 12999',
#  'Rs. 9999',
#  'Rs. 7999',
#  'Rs. 7999',
#  'Rs. 8500Rs. 10500',
#  'Rs. 7999',
#  'Rs. 7900Rs. 8900',
#  'Rs. 11900Rs. 13900',
#  'Rs. 7990',
#  'Rs. 8999',
#  'Rs. 9999',
#  'Rs. 9800Rs. 13900',
#  'Rs. 9999',
#  'Rs. 7599',
#  'Rs. 9999',
#  'Rs. 7499',
#  'Rs. 9999',
#  'Rs. 9990',
#  'Rs. 8999',
#  'Rs. 9999',
#  'Rs. 8990',
#  'Rs. 8990',
#  'Rs. 7693Rs. 10990',
#  'Rs. 12510Rs. 13900',
#  'Rs. 8999',
#  'Rs. 7999']

# %%
pt=[]
for i in price:
    if len(i)>9:
        if len(i)==16:
            j=i[:-8]
        else:
            j=i[:-9]
        pt.append(j)
    else:
        pt.append(i)

# %%
pt
# Out:
# ['Rs. 7195',
#  'Rs. 8999',
#  'Rs. 9999',
#  'Rs. 8295',
#  'Rs. 7195',
#  'Rs. 8449',
#  'Rs. 7999',
#  'Rs. 7995',
#  'Rs. 7499',
#  'Rs. 9999',
#  'Rs. 9999',
#  'Rs. 7499',
#  'Rs. 9999',
#  'Rs. 9999',
#  'Rs. 10599',
#  'Rs. 8999',
#  'Rs. 9099',
#  'Rs. 9999',
#  'Rs. 11999',
#  'Rs. 8999',
#  'Rs. 7699',
#  'Rs. 8990',
#  'Rs. 8999',
#  'Rs. 8499',
#  'Rs. 7799',
#  'Rs. 9999',
#  'Rs. 7999',
#  'Rs. 7999',
#  'Rs. 8500',
#  'Rs. 7999',
#  'Rs. 7900',
#  'Rs. 11900',
#  'Rs. 7990',
#  'Rs. 8999',
#  'Rs. 9999',
#  'Rs. 9800',
#  'Rs. 9999',
#  'Rs. 7599',
#  'Rs. 9999',
#  'Rs. 7499',
#  'Rs. 9999',
#  'Rs. 9990',
#  'Rs. 8999',
#  'Rs. 9999',
#  'Rs. 8990',
#  'Rs. 8990',
#  'Rs. 7693',
#  'Rs. 12510',
#  'Rs. 8999',
#  'Rs. 7999']

# %%
for i in pt:
    if len(i)==0 or i=="(Rs. ":
        pt.remove(i)

# %%
len(pt)
# Out:
# 50

# %%
pt
# Out:
# ['Rs. 7195',
#  'Rs. 8999',
#  'Rs. 9999',
#  'Rs. 8295',
#  'Rs. 7195',
#  'Rs. 8449',
#  'Rs. 7999',
#  'Rs. 7995',
#  'Rs. 7499',
#  'Rs. 9999',
#  'Rs. 9999',
#  'Rs. 7499',
#  'Rs. 9999',
#  'Rs. 9999',
#  'Rs. 10599',
#  'Rs. 8999',
#  'Rs. 9099',
#  'Rs. 9999',
#  'Rs. 11999',
#  'Rs. 8999',
#  'Rs. 7699',
#  'Rs. 8990',
#  'Rs. 8999',
#  'Rs. 8499',
#  'Rs. 7799',
#  'Rs. 9999',
#  'Rs. 7999',
#  'Rs. 7999',
#  'Rs. 8500',
#  'Rs. 7999',
#  'Rs. 7900',
#  'Rs. 11900',
#  'Rs. 7990',
#  'Rs. 8999',
#  'Rs. 9999',
#  'Rs. 9800',
#  'Rs. 9999',
#  'Rs. 7599',
#  'Rs. 9999',
#  'Rs. 7499',
#  'Rs. 9999',
#  'Rs. 9990',
#  'Rs. 8999',
#  'Rs. 9999',
#  'Rs. 8990',
#  'Rs. 8990',
#  'Rs. 7693',
#  'Rs. 12510',
#  'Rs. 8999',
#  'Rs. 7999']

# %%
pts=pt

# %%
driver.get("https://www.myntra.com/shoes?f=Color%3ABlack_36454f&p=2&rf=Price%3A7149.0_14099.0_7149.0%20TO%2014099.0")

# %%
brandtag=driver.find_elements_by_xpath("//h3[@class='product-brand']")
brand.extend([i.text for i in brandtag])
brand
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['Nike',
#  'Puma',
#  'Skechers',
#  'Nike',
#  'Nike',
#  'Puma',
#  'ASICS',
#  'Nike',
#  'Puma',
#  'Calvin Klein',
#  'Hush Puppies',
#  'Skechers',
#  'Bugatti',
#  'Hush Puppies',
#  'Calvin Klein',
#  'Hush Puppies',
#  'Puma',
#  'Hush Puppies',
#  'Bugatti',
#  'Bugatti',
#  'Xtep',
#  'J.FONTINI',
#  'Calvin Klein',
#  'Skechers',
#  'Puma',
#  'ASICS',
#  'ASICS',
#  'Tommy Hilfiger',
#  'Saint G',
#  'Tommy Hilfiger',
#  'Saint G',
#  'Saint G',
#  'MANGO',
#  'Geox',
#  'Bugatti',
#  'Saint G',
#  'Geox',
#  'Tommy Hilfiger',
#  'Calvin Klein',
#  'fitflop',
#  'Hush Puppies',
#  'DAVINCHI',
#  'Calvin Klein',
#  'Hush Puppies',
#  'DAVINCHI',
#  'DAVINCHI',
#  'Heel & Buckle London',
#  'Saint G',
#  'ASICS',
#  'UNDER ARMOUR',
#  'Puma',
#  'UNDER ARMOUR',
#  'Geox',
#  'MANGO',
# ...

# %%
len(brand)
# Out:
# 100

# %%
desctag=driver.find_elements_by_xpath("//h4[@class='product-product']")
desc.extend([i.text for i in desctag])
desc
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['Men Zoom Span 4 Running Shoes',
#  'Men Deviate Nitro Running Shoe',
#  'Men Balance Anchor Walking',
#  'Men Waffle One SE Sneakers',
#  "Men BlazerLow '77 Sneakers",
#  'Men Running Shoes',
#  'Men Running Shoes',
#  'Men FLIGHT LEGACY Sneakers',
#  'Men Electrify Nitro Running',
#  'Men Textured Leather Sneaker',
#  'Men Solid Formal Slip-Ons',
#  'Men Go Run Pure 2 Axis Running',
#  'Men Running Shoes',
#  'Men Formal Derbys',
#  'Men Solid Mid-Top Sneakers',
#  'Men Solid Leather Formal Slip-Ons',
#  'Men Magnify Nitro Running',
#  'Men Solid Leather Formal Slip-Ons',
#  'Men Textured Leather High-Top Flat Boots',
#  'Men Black Walking Shoes',
#  'Men Running Shoes',
#  'Men Solid Loafers',
#  'Men UV MONO Leather Sneakers',
#  'Men Go Run Hyper Burst Running',
# ...

# %%
len(desc)
# Out:
# 100

# %%
price=[]
ptag=driver.find_elements_by_xpath("//div[@class='product-price']/span")
price.extend([i.text for i in ptag])

price
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['Rs. 7799Rs. 12999',
#  '(40% OFF)',
#  'Rs. 7499',
#  'Rs. 8999',
#  'Rs. 7990',
#  'Rs. 10999',
#  'Rs. 7599',
#  'Rs. 8999',
#  'Rs. 7999',
#  'Rs. 7999',
#  'Rs. 12999',
#  'Rs. 11999',
#  'Rs. 12999',
#  'Rs. 8999',
#  'Rs. 7990',
#  'Rs. 7990',
#  'Rs. 9999',
#  'Rs. 7999',
#  'Rs. 7999',
#  'Rs. 11490',
#  'Rs. 8990',
#  'Rs. 7999',
#  'Rs. 8990',
#  'Rs. 7990',
#  'Rs. 7990',
#  'Rs. 11999',
#  'Rs. 8990',
#  'Rs. 7699Rs. 10999',
#  '(30% OFF)',
#  'Rs. 8990',
#  'Rs. 7990',
#  'Rs. 9999',
#  'Rs. 7999',
#  'Rs. 8990',
#  'Rs. 13495',
#  'Rs. 8490',
#  'Rs. 9999',
#  'Rs. 11699Rs. 12999',
#  '(10% OFF)',
#  'Rs. 7499',
#  'Rs. 9995',
#  'Rs. 7999',
#  'Rs. 7990',
#  'Rs. 8999',
#  'Rs. 9999',
#  'Rs. 7990',
#  'Rs. 11999',
#  'Rs. 8999Rs. 11999',
#  '(25% OFF)',
#  'Rs. 12999',
# ...

# %%
for i in price:
    if "OFF" in i:
        price.remove(i)
price
pt=[]
for i in price:
    if len(i)>9:
        if len(i)==16:
            j=i[:-8]
        else:
            j=i[:-9]
        pt.append(j)
    else:
        pt.append(i)
for i in pt:
    if len(i)==0 or i=="(Rs. ":
        pt.remove(i)

# %%
pts.extend(pt)

# %%
len(pts)
# Out:
# 100

# %%
myntra_df=pd.DataFrame()
myntra_df['Brand']=brand
myntra_df["Product Description"]=desc
myntra_df["Price"]=pts
myntra_df
# Out:
#              Brand                       Product Description      Price
# 0             Nike             Men Zoom Span 4 Running Shoes   Rs. 7195
# 1             Puma            Men Deviate Nitro Running Shoe   Rs. 8999
# 2         Skechers                Men Balance Anchor Walking   Rs. 9999
# 3             Nike                Men Waffle One SE Sneakers   Rs. 8295
# 4             Nike                Men BlazerLow '77 Sneakers   Rs. 7195
# 5             Puma                         Men Running Shoes   Rs. 8449
# 6            ASICS                         Men Running Shoes   Rs. 7999
# 7             Nike                Men FLIGHT LEGACY Sneakers   Rs. 7995
# 8             Puma               Men Electrify Nitro Running   Rs. 7499
# 9     Calvin Klein              Men Textured Leather Sneaker   Rs. 9999
# 10    Hush Puppies                 Men Solid Formal Slip-Ons   Rs. 9999
# 11        Skechers            Men Go Run Pure 2 Axis Running   Rs. 7499
# ...

# %%
driver.close()

# %% [markdown]
# ## Q8

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
driver.get("https://www.amazon.in/s?k=laptop&rh=n%3A1375424031%2Cp_n_feature_thirteen_browse-bin%3A12598163031&dc&qid=1639041382&rnid=12598141031&ref=sr_nr_p_n_feature_thirteen_browse-bin_11")

# %%
title=[]
titletag=driver.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
title.extend([i.text for i in titletag])
title[:10]
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['Acer Nitro 5 AN515-57 Gaming Laptop | Intel Core i7-11800H |NVIDIA GeForce RTX 3050 Ti Laptop Graphics |15.6" FHD 144Hz IPS Display |16GB DDR4 |256GB SSD+1TB HDD |Killer Wi-Fi 6 |RGB Backlit Keyboard',
#  'Fujitsu UH-X 11th Gen Intel i7 Core 13.3 inches FHD IPS 400Nits Thin and Light Business Laptop (16GB/512GB SSD/Windows 10/Office/Iris Xe Graphics/Backlit Kb/ Fingerprint Reader/Black/0.878kg), 4ZR1D67596',
#  'Mi Notebook Pro QHD+ IPS Anti Glare Display Intel Core i7-11370H 11th Gen 14-inch(35.56 cms) Thin and Light Laptop (16GB/512GB SSD/Iris Xe Graphics/Win 10/Backlit KB/Fingerprint Sensor/1.4 Kg)',
# ...

# %%
#locating Ratings
Ratings=[]
urls=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")#collecting urls of all the laptop
UR=[]
for i in urls[:10]:
    UR.append(i.get_attribute('href'))#getting the url of first 10 laptops
for url in UR:#loop for every laptop in the list
    driver.get(url)
    try:                  #exception handling for nosuchelementexception                                                    #click the rating link found
        rating=driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']//span")#locating the rating
        Ratings.append(rating.text)#appending the ratings in Ratings list
        
    except NoSuchElementException:
        Ratings.append("NO rating")#appending the No rating if no rating is there
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   # Remove the CWD from sys.path while we load stuff.

# %%
Ratings
# Out:
# ['4 out of 5',
#  '4.3 out of 5',
#  '4.3 out of 5',
#  '4.3 out of 5',
#  '4.3 out of 5',
#  '3.3 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '4.4 out of 5',
#  '3.6 out of 5']

# %%
driver.get("https://www.amazon.in/s?k=laptop&rh=n%3A1375424031%2Cp_n_feature_thirteen_browse-bin%3A12598163031&dc&qid=1639041382&rnid=12598141031&ref=sr_nr_p_n_feature_thirteen_browse-bin_11")

# %%
price=[]
ptag=driver.find_elements_by_xpath("//span[@class='a-price-whole']")
price.extend([i.text for i in ptag])
price[:10]
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['89,990',
#  '92,990',
#  '72,999',
#  '1,03,390',
#  '84,990',
#  '43,199',
#  '89,990',
#  '89,990',
#  '72,990',
#  '95,289']

# %%
amazon_df=pd.DataFrame()
amazon_df["Title"]=title[:10]
amazon_df["Ratings"]=Ratings
amazon_df["Price(in Rs)"]=price[:10]
amazon_df
# Out:
#                                                Title       Ratings  \
# 0  Acer Nitro 5 AN515-57 Gaming Laptop | Intel Co...    4 out of 5
# 1  Fujitsu UH-X 11th Gen Intel i7 Core 13.3 inche...  4.3 out of 5
# 2  Mi Notebook Pro QHD+ IPS Anti Glare Display In...  4.3 out of 5
# 3  Lenovo Yoga 7i 11th Gen Intel Core i7-1165G7 1...  4.3 out of 5
# 4  HP Pavilion (2021) Intel 11th Gen Core i7 14 i...  4.3 out of 5
# 5  Life Digital Laptop 15.6-inch (39.62 cms) (Int...  3.3 out of 5
# 6  Acer Nitro 5 AN515-57 Gaming Laptop | Intel Co...    4 out of 5
# 7  HP Pavilion Gaming(2021) 10th Gen Intel Core i...    4 out of 5
# 8  MSI GF75 Thin, Intel i7-10750H, 17.3" (43.9 cm...  4.4 out of 5
# 9  Dell 15 (2021) i7-10870H Gaming Laptop, 16GB D...  3.6 out of 5
#
#   Price(in Rs)
# 0       89,990
# 1       92,990
# 2       72,999
# 3     1,03,390
# 4       84,990
# 5       43,199
# 6       89,990
# 7       89,990
# 8       72,990
# 9       95,289

# %%
driver.close()

# %% [markdown]
# ## Q9

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
driver.get("https://www.ambitionbox.com/jobs/search?tag=Data%20Scientist&location=Noida")

# %%
company=[]
companytag=driver.find_elements_by_xpath("//p[@class='company body-medium']")
company.extend([i.text for i in companytag])
company[:10]
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['GENPACT India Private Limited',
#  'GENPACT India Private Limited',
#  'NTT Data Business Solutions Pvt Ltd',
#  'GENPACT India Private Limited',
#  'GI Group',
#  'Steria India Ltd',
#  'GI Group',
#  'GI Group',
#  'Jubilant Foodworks Limited',
#  'Ameriprise Financial']

# %%
rating=[]
rt=driver.find_elements_by_xpath("//span[@class='body-small']")
rating.extend([i.text for i in rt])
rating[:10]
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['4.0', '4.0', '3.8', '4.0', '4.0', '4.1', '4.0', '4.0', '3.9', '3.9']

# %%
dt=[]
ddt=driver.find_elements_by_xpath("//span[@class='body-small-l']")
dt.extend([i.text for i in ddt])
dt[0:20:2]
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['4d ago',
#  '4d ago',
#  '5d ago',
#  '6d ago',
#  '2d ago',
#  '27d ago',
#  '6d ago',
#  '6d ago',
#  '26d ago',
#  '29d ago']

# %%
df=pd.DataFrame()
df['Company_name']=company[:10]
df["Rating"]=rating[:10]
df["No. of days ago job posted"]=dt[:20:2]
df
# Out:
#                           Company_name Rating No. of days ago job posted
# 0        GENPACT India Private Limited    4.0                     4d ago
# 1        GENPACT India Private Limited    4.0                     4d ago
# 2  NTT Data Business Solutions Pvt Ltd    3.8                     5d ago
# 3        GENPACT India Private Limited    4.0                     6d ago
# 4                             GI Group    4.0                     2d ago
# 5                     Steria India Ltd    4.1                    27d ago
# 6                             GI Group    4.0                     6d ago
# 7                             GI Group    4.0                     6d ago
# 8           Jubilant Foodworks Limited    3.9                    26d ago
# 9                 Ameriprise Financial    3.9                    29d ago

# %%
driver.close()

# %% [markdown]
# ## Q10

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
driver.get("https://www.ambitionbox.com/salaries")

# %%
company=[]
companytag=driver.find_elements_by_xpath("//div[@class='name']/a")
company.extend([i.text for i in companytag])
company
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['Ab Inbev',
#  'Fractal Analytics',
#  'Optum',
#  'Tiger Analytics',
#  'UnitedHealth',
#  'Verizon',
#  'Ganit Business Solutions',
#  'Deloitte',
#  'Ericsson',
#  'Ernst & Young']

# %%
total_sal=[]
total_sal_tag=driver.find_elements_by_xpath("//div[@class='name']/span")
total_sal.extend([i.text.split(" ")[2] for i in total_sal_tag])
total_sal
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['20', '63', '22', '26', '46', '14', '12', '50', '43', '25']

# %%
exp=[]
exptag=driver.find_elements_by_xpath("//div[@class='salaries sbold-list-header']")
exp.extend([i.text.replace("\n","").split(" ")[3] for i in exptag])
exp
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['3-4', '2-4', '3-4', '3-4', '2-4', '4', '4', '2-4', '3-4', '3-4']

# %%
min_sal=[]
minSal_tag=driver.find_elements_by_xpath("//div[@class='value body-medium']")
min_sal.extend([i.text for i in minSal_tag])
min_sal
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['₹ 15.0L',
#  '₹ 23.0L',
#  '₹ 9.0L',
#  '₹ 22.0L',
#  '₹ 11.0L',
#  '₹ 21.3L',
#  '₹ 8.3L',
#  '₹ 18.5L',
#  '₹ 7.2L',
#  '₹ 20.5L',
#  '₹ 10.0L',
#  '₹ 21.0L',
#  '₹ 8.5L',
#  '₹ 15.0L',
#  '₹ 6.5L',
#  '₹ 20.5L',
#  '₹ 5.0L',
#  '₹ 21.5L',
#  '₹ 6.0L',
#  '₹ 17.4L']

# %%
minimun_salary=min_sal[::2]

minimun_salary
# Out:
# ['₹ 15.0L',
#  '₹ 9.0L',
#  '₹ 11.0L',
#  '₹ 8.3L',
#  '₹ 7.2L',
#  '₹ 10.0L',
#  '₹ 8.5L',
#  '₹ 6.5L',
#  '₹ 5.0L',
#  '₹ 6.0L']

# %%
max_sal=min_sal[1::2]
max_sal
# Out:
# ['₹ 23.0L',
#  '₹ 22.0L',
#  '₹ 21.3L',
#  '₹ 18.5L',
#  '₹ 20.5L',
#  '₹ 21.0L',
#  '₹ 15.0L',
#  '₹ 20.5L',
#  '₹ 21.5L',
#  '₹ 17.4L']

# %%
avg_sal=[]
avgSal=driver.find_elements_by_xpath("//p[@class='averageCtc']")
avg_sal.extend([i.text for i in avgSal])
avg_sal
# Out:
# C:\Users\p.c\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
# ['₹ 19.0L',
#  '₹ 14.9L',
#  '₹ 14.9L',
#  '₹ 13.5L',
#  '₹ 13.4L',
#  '₹ 12.7L',
#  '₹ 12.4L',
#  '₹ 11.0L',
#  '₹ 10.9L',
#  '₹ 10.8L']

# %%
df=pd.DataFrame()
df['Company Name']=company
df['Experience Required(in years)']=exp
df["total salary record"]=total_sal
df["Minimum Salary"]=minimun_salary
df["Average Salary"]=avg_sal
df["Maximun Slary"]=max_sal
df
# Out:
#                Company Name Experience Required(in years) total salary record  \
# 0                  Ab Inbev                           3-4                  20
# 1         Fractal Analytics                           2-4                  63
# 2                     Optum                           3-4                  22
# 3           Tiger Analytics                           3-4                  26
# 4              UnitedHealth                           2-4                  46
# 5                   Verizon                             4                  14
# 6  Ganit Business Solutions                             4                  12
# 7                  Deloitte                           2-4                  50
# 8                  Ericsson                           3-4                  43
# 9             Ernst & Young                           3-4                  25
#
#   Minimum Salary Average Salary Maximun Slary
# 0        ₹ 15.0L        ₹ 19.0L       ₹ 23.0L
# ...

# %%
driver.close()
