# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
import time as ttime

import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Q1

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
info=[]
infot=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td")
info.extend(i.text for i in infot)

# %%
df1=pd.DataFrame()

df1['Rank']=info[:180:6]

df1['Name']=info[1:181:6]

df1['Artist']=info[2:182:6]

df1['views']=info[3:183:6]

df1['uploadDate']=info[4:184:6]
df1
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[5]
# 2    3.                       "Johny Johny Yes Papa"[11]
# 3    4.                               "Shape of You"[12]
# 4    5.                              "See You Again"[14]
# 5    6.                                  "Bath Song"[19]
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[20]
# 7    8.   "Masha and the Bear – Recipe for Disaster"[21]
# 8    9.                                "Uptown Funk"[22]
# 9   10.                "Phonics Song with Two Words"[23]
# 10  11.                              "Gangnam Style"[24]
# 11  12.                             "Dame Tu Cosita"[29]
# 12  13.                                      "Sugar"[30]
# 13  14.                                      "Sorry"[31]
# 14  15.                                       "Roar"[32]
# 15  16.                             "Counting Stars"[33]
# 16  17.                          "Wheels on the Bus"[34]
# 17  18.                          "Thinking Out Loud"[35]
# 18  19.                             "Girls Like You"[36]
# 19  20.                                      "Faded"[37]
# 20  21.                                 "Dark Horse"[38]
# 21  22.                                     "Axel F"[39]
# 22  23.                                 "Let Her Go"[40]
# 23  24.                                   "Bailando"[41]
# 24  25.                                    "Lean On"[42]
# 25  26.                               "Shake It Off"[43]
# 26  27.                                    "Perfect"[44]
# 27  28.                        "Baa Baa Black Sheep"[45]
# 28  29.           "Waka Waka (This Time for Africa)"[46]
# 29  30.                                   "Mi Gente"[47]
#
#                                          Artist views         uploadDate
# 0   Pinkfong Baby Shark - Kids' Songs & Stories  9.96      June 17, 2016
# 1                                    Luis Fonsi  7.69   January 12, 2017
# 2                                   LooLoo Kids  6.08    October 8, 2016
# 3                                    Ed Sheeran  5.58   January 30, 2017
# 4                                   Wiz Khalifa  5.38      April 6, 2015
# 5                    Cocomelon – Nursery Rhymes  4.83        May 2, 2018
# 6                                   Miroshka TV  4.55  February 27, 2018
# 7                                    Get Movies  4.48   January 31, 2012
# 8                                   Mark Ronson  4.42  November 19, 2014
# 9                                     ChuChu TV  4.39      March 6, 2014
# 10                                          Psy  4.30      July 15, 2012
# 11                                    El Chombo  3.79      April 5, 2018
# 12                                     Maroon 5  3.62   January 14, 2015
# 13                                Justin Bieber  3.50   October 22, 2015
# 14                                   Katy Perry  3.50  September 5, 2013
# 15                                  OneRepublic  3.48       May 31, 2013
# 16                   Cocomelon – Nursery Rhymes  3.47       May 24, 2018
# 17                                   Ed Sheeran  3.39    October 7, 2014
# 18                                     Maroon 5  3.21       May 31, 2018
# 19                                  Alan Walker  3.21   December 3, 2015
# 20                                   Katy Perry  3.20  February 20, 2014
# 21                                   Crazy Frog  3.16      June 16, 2009
# 22                                    Passenger  3.15      July 25, 2012
# 23                             Enrique Iglesias  3.15     April 11, 2014
# 24                                  Major Lazer  3.15     March 22, 2015
# 25                                 Taylor Swift  3.13    August 18, 2014
# 26                                   Ed Sheeran  3.06   November 9, 2017
# 27                   Cocomelon – Nursery Rhymes  3.05      June 25, 2018
# 28                                      Shakira  3.02       June 4, 2010
# 29                                     J Balvin  3.02      June 29, 2017

# %% [markdown]
# ## Q2

# %%
driver.get("https://www.bcci.tv/")

# %%
seachinternational=driver.find_element_by_xpath("//li[@class='nav-item ml-0']/a")
driver.get(seachinternational.get_attribute('href'))

# %%
try:
    format=driver.find_elements_by_xpath("//div[@class='cSBDisplay ng-binding']")
    format[1].click()
except:
    print("Error Occured")

# %%
formatODI=driver.find_elements_by_xpath("//div[@class='cSBListItems ng-scope']")
formatODI[1].click()

# %%
matchest=driver.find_elements_by_xpath("//span[@class='ng-binding']")
matches=[]
matches.append([i.text for i in matchest])
matches
# Out:
# [['INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22',
#   'INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22',
#   'INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22',
#   'WEST INDIES TOUR OF INDIA ODI SERIES 2022',
#   'WEST INDIES TOUR OF INDIA ODI SERIES 2022',
#   'WEST INDIES TOUR OF INDIA ODI SERIES 2022']]

# %%
series=[]
series.extend([i[-7:] for i in matches[0][:3]])
series.extend([i[-4:] for i in matches[0][3:]])
series
# Out:
# ['2021/22', '2021/22', '2021/22', '2022', '2022', '2022']

# %%
place=driver.find_elements_by_xpath("//div[@class='fix-place ng-binding ng-scope']")
venue=[]
venue.extend([i.text.split("-")[1] for i in place])
venue
# Out:
# [' Boland Park, Paarl',
#  ' Boland Park, Paarl',
#  ' Newlands, Cape Town',
#  ' NARENDRA MODI STADIUM, Ahmedabad',
#  ' Sawai Mansingh Stadium, Jaipur',
#  ' Eden Gardens, Kolkata']

# %%
dateTag=driver.find_elements_by_xpath("//h5[@class='ng-binding']")
date=[]
date.extend([i.text for i in dateTag])
date
# Out:
# ['19 JAN 2022',
#  '21 JAN 2022',
#  '23 JAN 2022',
#  '6 FEB 2022',
#  '9 FEB 2022',
#  '12 FEB 2022']

# %%
timeTag=driver.find_elements_by_xpath("//h5[@class='text-right ng-binding']")
time=[]
time.extend([i.text for i in timeTag])
time
# Out:
# ['2:00 PM IST',
#  '2:00 PM IST',
#  '2:00 PM IST',
#  '9:30 AM IST',
#  '9:30 AM IST',
#  '9:30 AM IST']

# %%
df=pd.DataFrame()

df['Matches']=matches[0]

df['Series']=series

df['Place']=venue

df['date']=date

df['Time']=time
df
# Out:
#                                          Matches   Series  \
# 0  INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22  2021/22
# 1  INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22  2021/22
# 2  INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22  2021/22
# 3      WEST INDIES TOUR OF INDIA ODI SERIES 2022     2022
# 4      WEST INDIES TOUR OF INDIA ODI SERIES 2022     2022
# 5      WEST INDIES TOUR OF INDIA ODI SERIES 2022     2022
#
#                                Place         date         Time
# 0                 Boland Park, Paarl  19 JAN 2022  2:00 PM IST
# 1                 Boland Park, Paarl  21 JAN 2022  2:00 PM IST
# 2                Newlands, Cape Town  23 JAN 2022  2:00 PM IST
# 3   NARENDRA MODI STADIUM, Ahmedabad   6 FEB 2022  9:30 AM IST
# 4     Sawai Mansingh Stadium, Jaipur   9 FEB 2022  9:30 AM IST
# 5              Eden Gardens, Kolkata  12 FEB 2022  9:30 AM IST

# %% [markdown]
# ## Q3

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
driver.get("https://www.guru99.com/")

# %%
driver.find_elements_by_xpath("//span[@class='kadence-svg-iconset']")[0].click()

# %%
searchBar=driver.find_element_by_xpath("//input[@class='gsc-input']")
searchBar.send_keys("selenium exception")

# %%
clickButton=driver.find_element_by_xpath("//button[@class='gsc-search-button gsc-search-button-v2']")
clickButton.click()

# %%
urls=[]
try:
    urlTag=driver.find_elements_by_xpath("//a[@class='gs-title']")
    urls.extend([i.get_attribute('href') for i in urlTag[:20:2]])
except:
    urls.append('-')

# %%
urls
# Out:
# ['https://www.guru99.com/exception-handling-selenium.html',
#  'https://www.guru99.com/implicit-explicit-waits-selenium.html',
#  'https://www.guru99.com/alert-popup-handling-selenium.html',
#  'https://www.guru99.com/top-100-selenium-interview-questions-answers.html',
#  'https://www.guru99.com/ssl-certificate-error-handling-selenium.html',
#  'https://www.guru99.com/gecko-marionette-driver-selenium.html',
#  'https://www.guru99.com/test-case-priority-testng.html',
#  'https://www.guru99.com/java-exception-handling.html',
#  'https://www.guru99.com/take-screenshot-selenium-webdriver.html',
#  'https://www.guru99.com/selenium-tutorial.html']

# %%
Name=[]
desc=[]
try:
    for i in urls:
        driver.get(i)
        NameTag=driver.find_element_by_xpath("//h1[@class='entry-title']")
        Name.append(NameTag.text)
        descTag=driver.find_elements_by_xpath("//div/p")
        desc.extend([j.text for j in descTag[:2]])
except:
    Name.append("-")
    desc.append("-")

# %%
len(Name)
# Out:
# 10

# %%
description=[]
for i in range(0,len(desc),2):
    description.append(desc[i]+desc[i+1])

# %%
df=pd.DataFrame()
df['Name']=Name
df['Description']=description

# %%
df
# Out:
#                                                 Name  \
# 0  Selenium Exception Handling (Common Exceptions...
# 1  Implicit, Explicit and Fluent Wait in Selenium...
# 2  Selenium Alert & Popup Window Handling: How to...
# 3  Top 100 Selenium Interview Questions and Answe...
# 4  How to Handle SSL Certificate in Selenium WebD...
# 5  Download Geckodriver: How to Install Using Fir...
# 6                  TestNG @Test Priority in Selenium
# 7      Try Catch in Java: Exception Handling Example
# 8       How to Take Screenshot in Selenium WebDriver
# 9  Selenium Tutorial for Beginners: Learn WebDriv...
#
#                                          Description
# 0  An exception is an error that happens at the t...
# 1
# 2
# 3
# 4  SSL (Secure Sockets Layer) is a standard secur...
# 5  The term Gecko stands for a Web Browser engine...
# 6  TestNG is a Testing framework, that covers dif...
# 7  Exception in Java is an event that interrupts ...
# 8  A Screenshot in Selenium Webdriver is used for...
# 9  Selenium is a popular open-source web-based au...

# %% [markdown]
# ## Q4

# %%
driver.get("http://statisticstimes.com/")

# %%
economyTag=driver.find_elements_by_xpath("//button[@class='dropbtn']")
economyTag[1].click()

# %%
try:
    IndiaTag=driver.find_elements_by_xpath("//div[@class='dropdown-content']/a")
    driver.get(IndiaTag[4].get_attribute('href'))
except:
    print("Error")

# %%
driver.get(driver.find_elements_by_xpath("//a[@class='ec']")[13].get_attribute('href'))

# %%
Rank=[]
state=[]
GSDP=[]
GSDP18_19=[]
try:
    rankTag=driver.find_elements_by_xpath("//td[@class='data1']")
    Rank.extend([i.text for i in rankTag[:33]])
    state.extend([i.text for i in driver.find_elements_by_xpath("//td[@class='name']")][:33])
    GSDP18_19.extend([i.text for i in driver.find_elements_by_xpath("//td[@class='data sorting_1']")][:33])
    GSDP.extend([i.text for i in driver.find_elements_by_xpath("//td[@class='data']")][:165])
except:
    Rank.append("-")
    state.append("-")
    GSDP.append("-")
    GSDP18_19.append("-")

# %%
GSDP19_20=GSDP[::5]
GSDP19_20
Share=GSDP[1::5]
GDP=GSDP[2::5]
GSDPat11_12_1920=GSDP[3::5]
GSDPat11_12_1819=GSDP[4::5]

# %%
df=pd.DataFrame()
df['Rank']=Rank
df['State']=state
df['GSDP (Cr INR at Current prices) 19-20']=GSDP19_20
df['GSDP (Cr INR at Current prices) 18-19']=GSDP18_19
df['shares']=Share
df['GDP ($billion)']=GDP
df['GSDP (Cr INR at 2011-12 prices) 19-20']=GSDPat11_12_1920
df['GSDP (Cr INR at 2011-12 prices) 18-19']=GSDPat11_12_1819

# %%
df
# Out:
#    Rank                      State GSDP (Cr INR at Current prices) 19-20  \
# 0     1                Maharashtra                                     -
# 1     2                 Tamil Nadu                             1,845,853
# 2     3              Uttar Pradesh                             1,687,818
# 3     4                    Gujarat                                     -
# 4     5                  Karnataka                             1,631,977
# 5     6                West Bengal                             1,253,832
# 6     7                  Rajasthan                             1,020,989
# 7     8             Andhra Pradesh                               972,782
# 8     9                  Telangana                               969,604
# 9    10             Madhya Pradesh                               906,672
# 10   11                     Kerala                                     -
# 11   12                      Delhi                               856,112
# 12   13                    Haryana                               831,610
# 13   14                      Bihar                               611,804
# 14   15                     Punjab                               574,760
# 15   16                     Odisha                               521,275
# 16   17                      Assam                                     -
# 17   18               Chhattisgarh                               329,180
# 18   19                  Jharkhand                               328,598
# 19   20                Uttarakhand                                     -
# 20   21            Jammu & Kashmir                                     -
# 21   22           Himachal Pradesh                               165,472
# 22   23                        Goa                                80,449
# 23   24                    Tripura                                55,984
# 24   25                 Chandigarh                                     -
# 25   26                 Puducherry                                38,253
# 26   27                  Meghalaya                                36,572
# 27   28                     Sikkim                                32,496
# 28   29                    Manipur                                31,790
# 29   30                   Nagaland                                     -
# 30   31          Arunachal Pradesh                                     -
# 31   32                    Mizoram                                26,503
# 32   33  Andaman & Nicobar Islands                                     -
#
#    GSDP (Cr INR at Current prices) 18-19  shares GDP ($billion)  \
# 0                              2,632,792  13.94%        399.921
# 1                              1,630,208   8.63%        247.629
# 2                              1,584,764   8.39%        240.726
# 3                              1,502,899   7.96%        228.290
# 4                              1,493,127   7.91%        226.806
# 5                              1,089,898   5.77%        165.556
# 6                                942,586   4.99%        143.179
# 7                                862,957   4.57%        131.083
# 8                                861,031   4.56%        130.791
# 9                                809,592   4.29%        122.977
# 10                               781,653   4.14%        118.733
# 11                               774,870   4.10%        117.703
# 12                               734,163   3.89%        111.519
# 13                               530,363   2.81%         80.562
# 14                               526,376   2.79%         79.957
# 15                               487,805   2.58%         74.098
# 16                               315,881   1.67%         47.982
# 17                               304,063   1.61%         46.187
# 18                               297,204   1.57%         45.145
# 19                               245,895   1.30%         37.351
# 20                               155,956   0.83%         23.690
# 21                               153,845   0.81%         23.369
# 22                                73,170   0.39%         11.115
# 23                                49,845   0.26%          7.571
# 24                                42,114   0.22%          6.397
# 25                                34,433   0.18%          5.230
# 26                                33,481   0.18%          5.086
# 27                                28,723   0.15%          4.363
# 28                                27,870   0.15%          4.233
# 29                                27,283   0.14%          4.144
# 30                                24,603   0.13%          3.737
# 31                                22,287   0.12%          3.385
# 32                                     -       -              -
#
#    GSDP (Cr INR at 2011-12 prices) 19-20 GSDP (Cr INR at 2011-12 prices) 18-19
# 0                                      -                             2,039,074
# 1                              1,312,929                             1,215,307
# 2                              1,166,817                             1,123,982
# 3                                      -                             1,186,379
# 4                              1,156,039                             1,091,077
# 5                                793,223                               739,525
# 6                                711,627                               677,428
# 7                                672,018                               621,301
# 8                                663,258                               612,828
# 9                                561,801                               522,009
# 10                                     -                               559,412
# 11                               634,408                               590,569
# 12                               572,240                               531,085
# 13                               414,977                               375,651
# 14                               418,868                               397,669
# 15                               396,499                               376,877
# 16                                     -                               234,048
# 17                               243,477                               231,182
# 18                               240,036                               224,986
# 19                                     -                               193,273
# 20                                     -                               112,755
# 21                               124,403                               117,851
# 22                                63,408                                57,787
# 23                                40,583                                36,963
# 24                                     -                                31,192
# 25                                25,093                                23,013
# 26                                26,695                                24,682
# 27                                20,017                                18,722
# 28                                20,673                                19,300
# 29                                     -                                17,647
# 30                                     -                                16,676
# 31                                18,797                                16,478
# 32                                     -                                     -

# %%
driver.close()

# %% [markdown]
# ## Q5

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
driver.get("https://github.com/")

# %%
try:
    driver.find_elements_by_xpath("//details[@class='HeaderMenu-details details-overlay details-reset width-full']")[1].click()
except:
    print("Error!!")

# %%
try:
    driver.get(driver.find_elements_by_xpath("//a[@class='lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2']")[10].get_attribute('href'))
except:
    print("Error!!")

# %%
url=[]
try:
    urlTag=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']/a")
    url.extend([i.get_attribute('href') for i in urlTag])
except:
    print("Error!!")

# %%
Repository_title=[]
Repository_description=[]
Contributors_count=[]
Language_used=[]
for i in url:
    driver.get(i)
    try:
        Repository_title.append(driver.find_element_by_xpath("//strong[@class='mr-2 flex-self-stretch']").text)
    except:
        Repository_title.append("-")
    try:
        Repository_description.append(driver.find_element_by_xpath("//div[@class='BorderGrid-cell']/p").text)
    except:
        Repository_description.append("-")
    try:
        Contributors_count.append(driver.find_elements_by_xpath("//h2[@class='h4 mb-3']/a/span")[-1].text)
    except:
        Contributors_count.append("-")
    try:
        Language_used.append(driver.find_element_by_xpath("//span[@class='color-fg-default text-bold mr-1']").text)
    except:
        Language_used.append("-")

# %%
len(Repository_title)
# Out:
# 25

# %%
Repository_title
# Out:
# ['30-Days-Of-JavaScript',
#  'awesome-piracy',
#  'HelloGitHub',
#  'holehe',
#  'xquic',
#  'Python',
#  'freeCodeCamp',
#  'slide_puzzle',
#  'java-design-patterns',
#  'faker.js',
#  'hello-wordl',
#  'Java',
#  'flash-linux0.11-talk',
#  'modern-unix',
#  'kaggle-solutions',
#  'bumblebee',
#  'MagicMirror',
#  'laravel-tips',
#  'BookStack',
#  'awesome-java',
#  'PowerToys',
#  'interviews',
#  'weekly',
#  'mae',
#  'crypto-reading-list']

# %%
df=pd.DataFrame()
df['Repository_title']=Repository_title
df['Repository_description']=Repository_description
df['Contributors_count']=Contributors_count
df['Language_used']=Language_used
df
# Out:
#          Repository_title                             Repository_description  \
# 0   30-Days-Of-JavaScript  30 days of JavaScript programming challenge is...
# 1          awesome-piracy   A curated list of awesome warez and piracy links
# 2             HelloGitHub  分享 GitHub 上有趣、入门级的开源项目。Share interesting, entr...
# 3                  holehe  holehe allows you to check if the mail is used...
# 4                   xquic                                                  -
# 5                  Python               All Algorithms implemented in Python
# 6            freeCodeCamp  freeCodeCamp.org's open-source codebase and cu...
# 7            slide_puzzle                                                  -
# 8    java-design-patterns                Design patterns implemented in Java
# 9                faker.js                                                  -
# 10            hello-wordl                  Wordle clone you can play forever
# 11                   Java                 All Algorithms implemented in Java
# 12   flash-linux0.11-talk            你管这破玩意叫操作系统源码 — 像小说一样品读 Linux 0.11 核心代码
# 13            modern-unix  A collection of modern/faster/saner alternativ...
# 14       kaggle-solutions       🏅 Collection of Kaggle Solutions and Ideas 🏅
# 15              bumblebee  Get eBPF programs running from the cloud to th...
# 16            MagicMirror  MagicMirror² is an open source modular smart m...
# 17           laravel-tips                           Awesome tips for Laravel
# 18              BookStack  A platform to create documentation/wiki conten...
# 19           awesome-java  A curated list of awesome frameworks, librarie...
# 20              PowerToys  Windows system utilities to maximize productivity
# 21             interviews        Everything you need to know to get the job.
# 22                 weekly                              前端精读周刊。帮你理解最前沿、实用的技术。
# 23                    mae  PyTorch implementation of MAE https//arxiv.org...
# 24    crypto-reading-list                                                  -
#
#    Contributors_count Language_used
# 0                  18    JavaScript
# 1                 118          HTML
# 2                  11        Python
# 3                  14        Python
# 4                   6             C
# 5                 792        Python
# 6               4,374    JavaScript
# 7                   4          Dart
# 8                 270          Java
# 9                 200    JavaScript
# 10                       TypeScript
# 11                336          Java
# 12                 14             C
# 13                 10             -
# 14                             HTML
# 15                  8             C
# 16                281    JavaScript
# 17                 38             -
# 18                145           PHP
# 19                314             -
# 20                262            C#
# 21                 30          Java
# 22                 58    JavaScript
# 23                  2        Python
# 24                  2             -

# %% [markdown]
# ## Q6

# %%
driver.get("http://www.billboard.com/")

# %%
driver.find_element_by_xpath("//button[@class='o-icon-button lrv-a-unstyle-button lrv-a-unstyle-link lrv-u-cursor-pointer lrv-u-flex js-MegaMenu-Trigger lrv-u-color-grey:hover lrv-a-hover-effect']").click()

# %%
url=driver.find_elements_by_xpath("//a[@class='c-link  lrv-a-unstyle-link lrv-u-font-size-18@desktop lrv-u-color-grey:hover u-color-brand-secondary:hover@desktop-max u-padding-a-1@desktop-max lrv-u-padding-tb-025 lrv-u-display-block']")
urls=url[0].get_attribute('href')

# %%
driver.get(urls)

# %%
Name=[]
Name.append(driver.find_element_by_xpath("//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet']").text)

# %%
Artist=[]
Artist.append(driver.find_element_by_xpath("//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet']").text)

# %%
rank=[]
rankTag=driver.find_elements_by_xpath("//span[@class='c-label  a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet']")
rank.extend([i.text for i in rankTag[:3]])

# %%
rank
# Out:
# ['1', '1', '51']

# %%
nameTag=driver.find_elements_by_xpath("//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 lrv-u-font-size-18@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-330 u-max-width-230@tablet-only']")
Name.extend([i.text for i in nameTag])

# %%
artistTag=driver.find_elements_by_xpath("//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
Artist.extend([i.text for i in artistTag])

# %%
Rank=[]
RankTag=driver.find_elements_by_xpath("//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
Rank.extend([i.text for i in RankTag])

# %%
Rank
# Out:
# ['5',
#  '1',
#  '12',
#  '',
#  '',
#  '',
#  '2',
#  '2',
#  '45',
#  '',
#  '',
#  '',
#  '3',
#  '3',
#  '42',
#  '',
#  '',
#  '',
#  '4',
#  '4',
#  '26',
#  '',
#  '',
#  '',
#  '9',
#  '1',
#  '25',
#  '',
#  '',
#  '',
#  '15',
#  '7',
#  '50',
#  '',
#  '',
#  '',
#  '6',
#  '5',
#  '27',
#  '',
#  '',
#  '',
#  '23',
#  '5',
#  '16',
#  '',
#  '',
#  '',
#  '8',
#  '6',
#  '20',
#  '',
#  '',
#  '',
#  '7',
#  '7',
#  '25',
#  '',
#  '',
#  '',
#  '22',
#  '1',
#  '23',
#  '',
#  '',
#  '',
#  '17',
#  '12',
#  '12',
#  '',
#  '',
#  '',
#  '24',
#  '8',
#  '29',
#  '',
#  '',
#  '',
#  '10',
#  '10',
#  '16',
#  '',
#  '',
#  '',
#  '26',
#  '16',
#  '8',
#  '',
#  '',
#  '',
#  '27',
#  '15',
#  '6',
#  '',
#  '',
#  '',
#  '11',
#  '11',
#  '32',
#  '',
#  '',
#  '',
#  '31',
#  '2',
#  '27',
#  '',
#  '',
#  '',
#  '29',
#  '11',
#  '17',
#  '',
#  '',
#  '',
#  '13',
#  '12',
#  '15',
#  '',
#  '',
#  '',
#  '16',
#  '16',
#  '12',
#  '',
#  '',
#  '',
#  '18',
#  '17',
#  '13',
#  '',
#  '',
#  '',
#  '19',
#  '16',
#  '17',
#  '',
#  '',
#  '',
#  '21',
#  '12',
#  '25',
#  '',
#  '',
#  '',
#  '25',
#  '10',
#  '14',
#  '',
#  '',
#  '',
#  '20',
#  '18',
#  '13',
#  '',
#  '',
#  '',
#  '32',
#  '5',
#  '8',
#  '',
#  '',
#  '',
#  '28',
#  '22',
#  '12',
#  '',
#  '',
#  '',
#  '14',
#  '14',
#  '2',
#  '',
#  '',
#  '',
#  '38',
#  '1',
#  '33',
#  '',
#  '',
#  '',
#  '39',
#  '32',
#  '14',
#  '',
#  '',
#  '',
#  '45',
#  '3',
#  '28',
#  '',
#  '',
#  '',
#  '12',
#  '8',
#  '19',
#  '',
#  '',
#  '',
#  '49',
#  '10',
#  '15',
#  '',
#  '',
#  '',
#  '-',
#  '9',
#  '25',
#  '',
#  '',
#  '',
#  '33',
#  '33',
#  '4',
#  '',
#  '',
#  '',
#  '-',
#  '3',
#  '37',
#  '',
#  '',
#  '',
#  '50',
#  '6',
#  '8',
#  '',
#  '',
#  '',
#  '57',
#  '5',
#  '6',
#  '',
#  '',
#  '',
#  '48',
#  '41',
#  '2',
#  '',
#  '',
#  '',
#  '-',
#  '11',
#  '26',
#  '',
#  '',
#  '',
#  '51',
#  '11',
#  '22',
#  '',
#  '',
#  '',
#  '54',
#  '30',
#  '20',
#  '',
#  '',
#  '',
#  '35',
#  '35',
#  '3',
#  '',
#  '',
#  '',
#  '56',
#  '29',
#  '11',
#  '',
#  '',
#  '',
#  '30',
#  '20',
#  '10',
#  '',
#  '',
#  '',
#  '52',
#  '31',
#  '15',
#  '',
#  '',
#  '',
#  '42',
#  '7',
#  '4',
#  '',
#  '',
#  '',
#  '-',
#  '50',
#  '1',
#  '',
#  '',
#  '',
#  '59',
#  '30',
#  '21',
#  '',
#  '',
#  '',
#  '53',
#  '4',
#  '17',
#  '',
#  '',
#  '',
#  '58',
#  '1',
#  '17',
#  '',
#  '',
#  '',
#  '-',
#  '54',
#  '1',
#  '',
#  '',
#  '',
#  '61',
#  '39',
#  '26',
#  '',
#  '',
#  '',
#  '60',
#  '21',
#  '16',
#  '',
#  '',
#  '',
#  '64',
#  '57',
#  '13',
#  '',
#  '',
#  '',
#  '66',
#  '32',
#  '24',
#  '',
#  '',
#  '',
#  '65',
#  '2',
#  '17',
#  '',
#  '',
#  '',
#  '73',
#  '59',
#  '14',
#  '',
#  '',
#  '',
#  '67',
#  '17',
#  '12',
#  '',
#  '',
#  '',
#  '69',
#  '62',
#  '10',
#  '',
#  '',
#  '',
#  '72',
#  '53',
#  '14',
#  '',
#  '',
#  '',
#  '70',
#  '64',
#  '6',
#  '',
#  '',
#  '',
#  '63',
#  '63',
#  '5',
#  '',
#  '',
#  '',
#  '68',
#  '1',
#  '7',
#  '',
#  '',
#  '',
#  '55',
#  '55',
#  '4',
#  '',
#  '',
#  '',
#  '75',
#  '28',
#  '16',
#  '',
#  '',
#  '',
#  '62',
#  '62',
#  '5',
#  '',
#  '',
#  '',
#  '82',
#  '65',
#  '12',
#  '',
#  '',
#  '',
#  '76',
#  '62',
#  '22',
#  '',
#  '',
#  '',
#  '84',
#  '1',
#  '14',
#  '',
#  '',
#  '',
#  '86',
#  '73',
#  '12',
#  '',
#  '',
#  '',
#  '71',
#  '71',
#  '4',
#  '',
#  '',
#  '',
#  '80',
#  '75',
#  '13',
#  '',
#  '',
#  '',
#  '78',
#  '58',
#  '5',
#  '',
#  '',
#  '',
#  '83',
#  '77',
#  '5',
#  '',
#  '',
#  '',
#  '92',
#  '78',
#  '6',
#  '',
#  '',
#  '',
#  '-',
#  '79',
#  '1',
#  '',
#  '',
#  '',
#  '93',
#  '45',
#  '7',
#  '',
#  '',
#  '',
#  '90',
#  '81',
#  '6',
#  '',
#  '',
#  '',
#  '74',
#  '34',
#  '3',
#  '',
#  '',
#  '',
#  '-',
#  '83',
#  '1',
#  '',
#  '',
#  '',
#  '81',
#  '81',
#  '4',
#  '',
#  '',
#  '',
#  '89',
#  '68',
#  '12',
#  '',
#  '',
#  '',
#  '94',
#  '48',
#  '15',
#  '',
#  '',
#  '',
#  '97',
#  '87',
#  '2',
#  '',
#  '',
#  '',
#  '-',
#  '53',
#  '3',
#  '',
#  '',
#  '',
#  '-',
#  '87',
#  '7',
#  '',
#  '',
#  '',
#  '-',
#  '79',
#  '7',
#  '',
#  '',
#  '',
#  '96',
#  '20',
#  '11',
#  '',
#  '',
#  '',
#  '-',
#  '92',
#  '1',
#  '',
#  '',
#  '',
#  '79',
#  '79',
#  '2',
#  '',
#  '',
#  '',
#  '-',
#  '94',
#  '1',
#  '',
#  '',
#  '',
#  '87',
#  '49',
#  '4',
#  '',
#  '',
#  '',
#  '-',
#  '96',
#  '1',
#  '',
#  '',
#  '',
#  '88',
#  '20',
#  '6',
#  '',
#  '',
#  '',
#  '98',
#  '13',
#  '8',
#  '',
#  '',
#  '',
#  '-',
#  '99',
#  '1',
#  '',
#  '',
#  '',
#  '100',
#  '18',
#  '18',
#  '',
#  '',
#  '']

# %%
len(Rank)
# Out:
# 594

# %%
for i in Rank:
    if i=='':
        Rank.remove(i)

# %%
len(Rank)
# Out:
# 297

# %%
Rank
# Out:
# ['5',
#  '1',
#  '12',
#  '2',
#  '2',
#  '45',
#  '3',
#  '3',
#  '42',
#  '4',
#  '4',
#  '26',
#  '9',
#  '1',
#  '25',
#  '15',
#  '7',
#  '50',
#  '6',
#  '5',
#  '27',
#  '23',
#  '5',
#  '16',
#  '8',
#  '6',
#  '20',
#  '7',
#  '7',
#  '25',
#  '22',
#  '1',
#  '23',
#  '17',
#  '12',
#  '12',
#  '24',
#  '8',
#  '29',
#  '10',
#  '10',
#  '16',
#  '26',
#  '16',
#  '8',
#  '27',
#  '15',
#  '6',
#  '11',
#  '11',
#  '32',
#  '31',
#  '2',
#  '27',
#  '29',
#  '11',
#  '17',
#  '13',
#  '12',
#  '15',
#  '16',
#  '16',
#  '12',
#  '18',
#  '17',
#  '13',
#  '19',
#  '16',
#  '17',
#  '21',
#  '12',
#  '25',
#  '25',
#  '10',
#  '14',
#  '20',
#  '18',
#  '13',
#  '32',
#  '5',
#  '8',
#  '28',
#  '22',
#  '12',
#  '14',
#  '14',
#  '2',
#  '38',
#  '1',
#  '33',
#  '39',
#  '32',
#  '14',
#  '45',
#  '3',
#  '28',
#  '12',
#  '8',
#  '19',
#  '49',
#  '10',
#  '15',
#  '-',
#  '9',
#  '25',
#  '33',
#  '33',
#  '4',
#  '-',
#  '3',
#  '37',
#  '50',
#  '6',
#  '8',
#  '57',
#  '5',
#  '6',
#  '48',
#  '41',
#  '2',
#  '-',
#  '11',
#  '26',
#  '51',
#  '11',
#  '22',
#  '54',
#  '30',
#  '20',
#  '35',
#  '35',
#  '3',
#  '56',
#  '29',
#  '11',
#  '30',
#  '20',
#  '10',
#  '52',
#  '31',
#  '15',
#  '42',
#  '7',
#  '4',
#  '-',
#  '50',
#  '1',
#  '59',
#  '30',
#  '21',
#  '53',
#  '4',
#  '17',
#  '58',
#  '1',
#  '17',
#  '-',
#  '54',
#  '1',
#  '61',
#  '39',
#  '26',
#  '60',
#  '21',
#  '16',
#  '64',
#  '57',
#  '13',
#  '66',
#  '32',
#  '24',
#  '65',
#  '2',
#  '17',
#  '73',
#  '59',
#  '14',
#  '67',
#  '17',
#  '12',
#  '69',
#  '62',
#  '10',
#  '72',
#  '53',
#  '14',
#  '70',
#  '64',
#  '6',
#  '63',
#  '63',
#  '5',
#  '68',
#  '1',
#  '7',
#  '55',
#  '55',
#  '4',
#  '75',
#  '28',
#  '16',
#  '62',
#  '62',
#  '5',
#  '82',
#  '65',
#  '12',
#  '76',
#  '62',
#  '22',
#  '84',
#  '1',
#  '14',
#  '86',
#  '73',
#  '12',
#  '71',
#  '71',
#  '4',
#  '80',
#  '75',
#  '13',
#  '78',
#  '58',
#  '5',
#  '83',
#  '77',
#  '5',
#  '92',
#  '78',
#  '6',
#  '-',
#  '79',
#  '1',
#  '93',
#  '45',
#  '7',
#  '90',
#  '81',
#  '6',
#  '74',
#  '34',
#  '3',
#  '-',
#  '83',
#  '1',
#  '81',
#  '81',
#  '4',
#  '89',
#  '68',
#  '12',
#  '94',
#  '48',
#  '15',
#  '97',
#  '87',
#  '2',
#  '-',
#  '53',
#  '3',
#  '-',
#  '87',
#  '7',
#  '-',
#  '79',
#  '7',
#  '96',
#  '20',
#  '11',
#  '-',
#  '92',
#  '1',
#  '79',
#  '79',
#  '2',
#  '-',
#  '94',
#  '1',
#  '87',
#  '49',
#  '4',
#  '-',
#  '96',
#  '1',
#  '88',
#  '20',
#  '6',
#  '98',
#  '13',
#  '8',
#  '-',
#  '99',
#  '1',
#  '100',
#  '18',
#  '18']

# %%
lastweekpos=Rank[0::3]
lastweekpos.insert(0,rank[0])
peakPos=Rank[1::3]
peakPos.insert(0,rank[1])
weeksonBoard=Rank[2::3]
weeksonBoard.insert(0,rank[2])

# %%
df=pd.DataFrame()
df['SongName']=Name
df['ArtistName']=Artist
df['Last Week']=lastweekpos
df["PeekPosition"]=peakPos
df['Weeks On board']=weeksonBoard
df
# Out:
#                                              SongName  \
# 0                     All I Want For Christmas Is You
# 1                                          Easy On Me
# 2                   Rockin' Around The Christmas Tree
# 3                                    Jingle Bell Rock
# 4                             A Holly Jolly Christmas
# 5                                                Stay
# 6                                          Heat Waves
# 7            It's The Most Wonderful Time Of The Year
# 8                                             Shivers
# 9                                       Feliz Navidad
# 10                                     Last Christmas
# 11                                      Industry Baby
# 12        It's Beginning To Look A Lot Like Christmas
# 13                                       Need To Know
# 14                                        Sleigh Ride
# 15                                      Super Gremlin
# 16                                            abcdefu
# 17        The Christmas Song (Merry Christmas To You)
# 18                                         Bad Habits
# 19                            Cold Heart (PNAU Remix)
# 20                                Underneath The Tree
# 21                  Christmas (Baby Please Come Home)
# 22                                      Santa Tell Me
# 23                     Rudolph The Red-Nosed Reindeer
# 24                                    White Christmas
# 25                                    Run Rudolph Run
# 26                 Happy Holiday / The Holiday Season
# 27                              Smokin Out The Window
# 28      (There's No Place Like) Home For The Holidays
# 29                                     Broadway Girls
# ..                                                ...
# 70                                              Woman
# 71                                        My Universe
# 72                              Freedom Was A Highway
# 73                         I'll Be Home For Christmas
# 74                                        For Tonight
# 75                                       By Your Side
# 76                                 To Be Loved By You
# 77                                      Heart On Fire
# 78                                     Christmas Tree
# 79  Message In A Bottle (Taylor's Version) (From T...
# 80                                            Scorpio
# 81                                               Burn
# 82                                        Hrs And Hrs
# 83                                       Life Goes On
# 84                                Tequila Little Time
# 85                                          Same Boat
# 86                                        Do It To It
# 87                                         Doin' This
# 88                                Half Of My Hometown
# 89                                        Poke It Out
# 90                                             Bubbly
# 91                                         I Am Woman
# 92                Christmas Isn't Canceled (Just You)
# 93                                           Pressure
# 94                                    Wandered To LA.
# 95                                        Beers On Me
# 96                                       Already Dead
# 97                                            No Love
# 98                                                 23
# 99                                        Family Ties
#
#                                            ArtistName Last Week PeekPosition  \
# 0                                        Mariah Carey         1            1
# 1                                               Adele         5            1
# 2                                          Brenda Lee         2            2
# 3                                         Bobby Helms         3            3
# 4                                           Burl Ives         4            4
# 5                       The Kid LAROI & Justin Bieber         9            1
# 6                                       Glass Animals        15            7
# 7                                       Andy Williams         6            5
# 8                                          Ed Sheeran        23            5
# 9                                      Jose Feliciano         8            6
# 10                                              Wham!         7            7
# 11                            Lil Nas X & Jack Harlow        22            1
# 12  Perry Como And The Fontane Sisters With Mitche...        17           12
# 13                                           Doja Cat        24            8
# 14                                       The Ronettes        10           10
# 15                                        Kodak Black        26           16
# 16                                              GAYLE        27           15
# 17                                      Nat King Cole        11           11
# 18                                         Ed Sheeran        31            2
# 19                              Elton John & Dua Lipa        29           11
# 20                                     Kelly Clarkson        13           12
# 21                                       Darlene Love        16           16
# 22                                      Ariana Grande        18           17
# 23                                         Gene Autry        19           16
# 24                                        Bing Crosby        21           12
# 25                                        Chuck Berry        25           10
# 26                                      Andy Williams        20           18
# 27           Silk Sonic (Bruno Mars & Anderson .Paak)        32            5
# 28                                         Perry Como        28           22
# 29                   Lil Durk Featuring Morgan Wallen        14           14
# ..                                                ...       ...          ...
# 70                                           Doja Cat        76           62
# 71                                     Coldplay x BTS        84            1
# 72                        Jimmie Allen & Brad Paisley        86           73
# 73                                     Camila Cabello        71           71
# 74                                             Giveon        80           75
# 75                                           Rod Wave        78           58
# 76                                    Parker McCollum        83           77
# 77                                        Eric Church        92           78
# 78                                                  V         -           79
# 79                                       Taylor Swift        93           45
# 80                                       Moneybagg Yo        90           81
# 81                                         Juice WRLD        74           34
# 82                                          Muni Long         -           83
# 83                                        Oliver Tree        81           81
# 84                                          Jon Pardi        89           68
# 85                                     Zac Brown Band        94           48
# 86                           Acraze Featuring Cherish        97           87
# 87                                         Luke Combs         -           53
# 88           Kelsea Ballerini Featuring Kenny Chesney         -           87
# 89                             Wale Featuring J. Cole         -           79
# 90               Young Thug With Drake & Travis Scott        96           20
# 91                                          Emmy Meli         -           92
# 92                                     Kelly Clarkson        79           79
# 93                                         Ari Lennox         -           94
# 94                         Juice WRLD & Justin Bieber        87           49
# 95                    Dierks Bentley, Breland & HARDY         -           96
# 96                                         Juice WRLD        88           20
# 97                                Summer Walker & SZA        98           13
# 98                                           Sam Hunt         -           99
# 99                         Baby Keem & Kendrick Lamar       100           18
#
#    Weeks On board
# 0              51
# 1              12
# 2              45
# 3              42
# 4              26
# 5              25
# 6              50
# 7              27
# 8              16
# 9              20
# 10             25
# 11             23
# 12             12
# 13             29
# 14             16
# 15              8
# 16              6
# 17             32
# 18             27
# 19             17
# 20             15
# 21             12
# 22             13
# 23             17
# 24             25
# 25             14
# 26             13
# 27              8
# 28             12
# 29              2
# ..            ...
# 70             22
# 71             14
# 72             12
# 73              4
# 74             13
# 75              5
# 76              5
# 77              6
# 78              1
# 79              7
# 80              6
# 81              3
# 82              1
# 83              4
# 84             12
# 85             15
# 86              2
# 87              3
# 88              7
# 89              7
# 90             11
# 91              1
# 92              2
# 93              1
# 94              4
# 95              1
# 96              6
# 97              8
# 98              1
# 99             18
#
# [100 rows x 5 columns]

# %%
driver.close()

# %% [markdown]
# ## Q7

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
driver.get(driver.find_element_by_xpath("//a[@title='Search Recruiters']").get_attribute("href"))

# %%
driver.find_element_by_xpath("//input[@class='sugInp']").send_keys("Data Science")

# %%
driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']").click()

# %%
Name=[]
Designation=[]
Company=[]
Skills_hire=[]
Location=[]
try:
    nameTag=driver.find_elements_by_xpath("//span[@class='fl ellipsis']")
    Name.extend([i.text for i in nameTag])
except:
    Name.append("-")
try:
    desTag=driver.find_elements_by_xpath("//span[@class='ellipsis clr']")
    Designation.extend([i.text for i in desTag])
except:
    Designation.append("-")

try:
    comTag=driver.find_elements_by_xpath("//a[@class='ellipsis']")[1::2]
    Company.extend([i.text for i in comTag])
except:
    Company.append("-")
    
try:
    skill=driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
    Skills_hire.extend([i.text for i in skill])
except:
    Skills_hire.append("-")

try:
    locTag=driver.find_elements_by_xpath("//small[@class='ellipsis']")
    try:
        Location.extend([i.text for i in locTag])
    except:
        Location.append("-")
except:
    Location.append("-")

# %%
df=pd.DataFrame()
df["name"]=Name
df['Designation']=Designation
df['Company']=Company
df['Skills_hireFor']=Skills_hire
df['Location']=Location
df
# Out:
#                                              name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                Sakshi Chhikara
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# 18                             Sandhya Khandagale
# 19                                  Manisha Yadav
# 20                                    Riya Rajesh
# 21                           Rashmi Bhattacharjee
# 22                                  Faizan Kareem
# 23                                 Rithika dadwal
# 24                                      Shaun Rao
# 25                                  Azahar Shaikh
# 26                                          Manas
# 27                                          kumar
# 28                                   Sunil Vedula
# 29                                    Rajat Kumar
# 30                                         Avodha
# 31                                      Jayanth N
# 32                                    Priya Khare
# 33                                Dhruv Dev Dubey
# 34                                    Amit Sharma
# 35                                          Kanan
# 36                           Shashikant Chaudhary
# 37                                           Brad
# 38                                   Rutuja Pawar
# 39                            Madhusudhan Sridhar
# 40                                    Ankit Sinha
# 41                                 Gaurav Chouhan
# 42                                   Rashi Kacker
# 43                                        Ashwini
# 44                                   Balaji Kolli
# 45                                 Rajani Nagaraj
# 46                                    ROHIT Kumar
# 47                                 Amir Chowdhury
# 48                                       SREEDHAR
# 49                              Radha Manivasagam
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                           Founder CEO
# 5           Recruitment Lead Consultant
# 6                     Programme Manager
# 7                      HR Administrator
# 8                              Director
# 9                        Human Resource
# 10                           HR Manager
# 11                     Executive Hiring
# 12                           Company HR
# 13                           Company HR
# 14                         HR Team Lead
# 15                 Assistant Manager HR
# 16                           HR Manager
# 17  Senior Executive Talent Acquisition
# 18                         HR Recruiter
# 19                         HR Executive
# 20           Manager Talent Acquisition
# 21                              HR Head
# 22                           HR MANAGER
# 23                         HR Recruiter
# 24              Manager Human Resources
# 25                    Company Recruiter
# 26              Lead Talent acquisition
# 27                           Proprietor
# 28                                  CEO
# 29                          Founder CEO
# 30       Business Development Associate
# 31                      Project Manager
# 32                       Senior Manager
# 33             Company Recruitment Head
# 34                           Consultant
# 35         senior technology instructor
# 36             HR Recruiter/HR Excutive
# 37        Manager, Technical Recruiting
# 38                  Technical Recruiter
# 39                      Erp Implementer
# 40                       Head Analytics
# 41              Chief Technical Officer
# 42                   Sr Product Manager
# 43             Director Global Delivery
# 44                           Co Founder
# 45                           HR Manager
# 46                            Architect
# 47                     Managing Partner
# 48               Recruitment Consultant
# 49                         HR Executive
#
#                                            Company  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                      Techvantage Systems Pvt Ltd
# 8                       Weupskill- Live Wire India
# 9                 CBL Data Science Private Limited
# 10                   Infinitive Software Solutions
# 11                              Innominds Software
# 12                                        MoneyTap
# 13              QuantMagnum Technologies Pvt. Ltd.
# 14                               SocialPrachar.com
# 15                   BIZ INFOTECNO PRIVATE LIMITED
# 16                                  BISP Solutions
# 17                           Bristlecone India Ltd
# 18                 Compumatrice Multimedia Pvt Ltd
# 19                                        Easi Tax
# 20                     Novelworx Digital Solutions
# 21         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 22                   FirstTech Consaltants Pvt.Ltd
# 23                                Affine Analytics
# 24                              Exela Technologies
# 25                 NEAL ANALYTICS SERVICES PVT LTD
# 26      Autumn Leaf Consulting Services Private...
# 27                                         trainin
# 28                            Nanoprecise Sci Corp
# 29                  R.S Consultancy &amp; Services
# 30                              Nikitha Palaparthi
# 31        Dollarbird Information Services Pvt, Ltd
# 32                          Independent Consultant
# 33                                    Confidential
# 34                                 ASCO consulting
# 35                                         NY INST
# 36  3D India Staffing Research &amp; Consulting...
# 37                                     O.C. Tanner
# 38                                   Demand Matrix
# 39                             MADHUSUDHAN SRIDHAR
# 40                                  Suntech Global
# 41                        Strategic Consulting Lab
# 42                            Impel Labs Pvt. Ltd.
# 43                                    MRP Advisers
# 44                   Saras Solutions India Pvt Ltd
# 45                                     WildJasmine
# 46                             LNT Private Limited
# 47                                     Granular.ai
# 48     JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED
# 49                                      Techcovery
#
#                                        Skills_hireFor  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Machine Learning, algorithms, Go Getter, Compu...
# 8   Technical Training, Software Development, Pres...
# 9   Software Development, It Sales, Account Manage...
# 10  Oracle Dba, Data Science, Data Warehousing, ET...
# 11  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 12  Business Intelligence, Data Warehousing, Data ...
# 13  Office Administration, Hr Administration, tele...
# 14  Social Media, digital media maketing, seo, smm...
# 15  React.js, Data Science, Java, Front End, Busin...
# 16     Big Data, Hadoop, Data Analytics, Data Science
# 17  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 18  Big Data, Data Science, Artificial Intelligenc...
# 19  Telecalling, Client Interaction, Marketing, Re...
# 20                                       Data Science
# 21  Corporate Sales, Software Development, Softwar...
# 22  Data Analytics, Data Science, Machine Learning...
# 23  Data Science, Machine Learning, Python, R, Dee...
# 24  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 25  Data Science, Artificial Intelligence, Machine...
# 26  Software Architecture, Vp Engineering, Product...
# 27  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 28  Signal Processing, Machine Learning, Neural Ne...
# 29  Web Technologies, Project Management, Software...
# 30  Ethical Hacking, Security Operations Center, S...
# 31  Data Analytics, Managed Services, Team Leading...
# 32  Data Science, Artificial Intelligence, analyti...
# 33  Server Administartion, Verilog, Vhdl, Digital ...
# 34  Machine Learning, Artificial Intelligence, Dat...
# 35  C, C++, Artificial Intelligence, Python, Php, ...
# 36  Relationship Management, Retail Sales, Private...
# 37                 Data Science, Software Engineering
# 38  Data Science, Big Data Analytics, Digital Mark...
# 39                  Data Science, Recruitment, Salary
# 40  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 41  Software Development, Business Intelligence, B...
# 42                   Data Science, Node.js, Angularjs
# 43  Data Science, Media Marketing, Resource Planni...
# 44  Data Analysis, Learning, Data Science, Compute...
# 45  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 46  Software Development, Core Java, Unit Testing,...
# 47  Machine Learning, Data Science, Product Manage...
# 48  Data Science, Machine Learning, Big Data Analy...
# 49  Python, Artificial Intelligence, Machine Learn...
#
#                     Location
# 0                      Delhi
# 1   Hyderabad / Secunderabad
# 2                       Pune
# 3                  Ahmedabad
# 4              UK - (london)
# 5          Vadodara / Baroda
# 6                    Chennai
# 7                 Trivandrum
# 8                     Indore
# 9      Bengaluru / Bangalore
# 10                 Hyderabad
# 11  Hyderabad / Secunderabad
# 12     Bengaluru / Bangalore
# 13                    Mumbai
# 14  Hyderabad / Secunderabad
# 15                Chandigarh
# 16                    Bhopal
# 17                      Pune
# 18                      Pune
# 19               Navi Mumbai
# 20                    Cochin
# 21                     Delhi
# 22  Hyderabad / Secunderabad
# 23                      Pune
# 24                      Pune
# 25                      Pune
# 26     Bengaluru / Bangalore
# 27     Bengaluru / Bangalore
# 28                         -
# 29                     Delhi
# 30  Hyderabad / Secunderabad
# 31           Mysoru / Mysore
# 32     Bengaluru / Bangalore
# 33     Bengaluru / Bangalore
# 34                 New Delhi
# 35                   Chennai
# 36                   Aligarh
# 37            Salt Lake City
# 38                      Pune
# 39     Bengaluru / Bangalore
# 40                    Mumbai
# 41                    Indore
# 42     Bengaluru / Bangalore
# 43                    MYSORE
# 44  Hyderabad / Secunderabad
# 45     Bengaluru / Bangalore
# 46                         -
# 47                    Mumbai
# 48  Hyderabad / Secunderabad
# 49     Bengaluru / Bangalore

# %%
driver.close()

# %% [markdown]
# ## q8

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/")

# %%
books=[]
genre=[]
try:
    bokks=driver.find_elements_by_xpath("//td[@class='left']")
    books.extend([i.text for i in bokks])
except:
    books.append("-")
    
try:
    genreTag=driver.find_elements_by_xpath("//td[@class='last left']")
    genre.extend([i.text for i in genreTag])
except:
    genre.append("-")

# %%
title=books[1::5]
author=books[2::5]
volSold=books[3::5]
publisher=books[4::5]

# %%
len(genre)
# Out:
# 100

# %%
df=pd.DataFrame()
df['bookName']=title
df['Author']=author
df['Volume_Sold']=volSold
df['Publisher']=publisher
df['genre']=genre
df
# Out:
#                                              bookName            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# 5                 Harry Potter and the Goblet of Fire     Rowling, J.K.
# 6             Harry Potter and the Chamber of Secrets     Rowling, J.K.
# 7            Harry Potter and the Prisoner of Azkaban     Rowling, J.K.
# 8                                   Angels and Demons        Brown, Dan
# 9   Harry Potter and the Half-blood Prince:Childre...     Rowling, J.K.
# 10                                Fifty Shades Darker      James, E. L.
# 11                                           Twilight  Meyer, Stephenie
# 12  Girl with the Dragon Tattoo,The:Millennium Tri...    Larsson, Stieg
# 13                                 Fifty Shades Freed      James, E. L.
# 14                                    Lost Symbol,The        Brown, Dan
# 15                                           New Moon  Meyer, Stephenie
# 16                                    Deception Point        Brown, Dan
# 17                                            Eclipse  Meyer, Stephenie
# 18                                   Lovely Bones,The     Sebold, Alice
# 19  Curious Incident of the Dog in the Night-time,The      Haddon, Mark
# 20                                   Digital Fortress        Brown, Dan
# 21               Short History of Nearly Everything,A      Bryson, Bill
# 22   Girl Who Played with Fire,The:Millennium Trilogy    Larsson, Stieg
# 23                                      Breaking Dawn  Meyer, Stephenie
# 24  Very Hungry Caterpillar,The:The Very Hungry Ca...       Carle, Eric
# 25                                       Gruffalo,The  Donaldson, Julia
# 26                            Jamie's 30-Minute Meals     Oliver, Jamie
# 27                                    Kite Runner,The  Hosseini, Khaled
# 28                                            One Day   Nicholls, David
# 29                           Thousand Splendid Suns,A  Hosseini, Khaled
# ..                                                ...               ...
# 70  Stupid White Men:...and Other Sorry Excuses fo...    Moore, Michael
# 71                       Interpretation of Murder,The    Rubenfeld, Jed
# 72           Sharon Osbourne Extreme:My Autobiography  Osbourne, Sharon
# 73   Alchemist,The:A Fable About Following Your Dream     Coelho, Paulo
# 74       At My Mother's Knee ...:and Other Low Joints     O'Grady, Paul
# 75                          Notes from a Small Island      Bryson, Bill
# 76                       Return of the Naked Chef,The     Oliver, Jamie
# 77                  Bridget Jones: The Edge of Reason   Fielding, Helen
# 78                                      Jamie's Italy     Oliver, Jamie
# 79                                I Can Make You Thin     McKenna, Paul
# 80                                         Down Under      Bryson, Bill
# 81                                        Summons,The     Grisham, John
# 82                                       Small Island      Levy, Andrea
# 83                                    Nigella Express   Lawson, Nigella
# 84                                         Brick Lane       Ali, Monica
# 85                       Memory Keeper's Daughter,The      Edwards, Kim
# 86                                  Room on the Broom  Donaldson, Julia
# 87                                        About a Boy      Hornby, Nick
# 88                                      My Booky Wook    Brand, Russell
# 89                                   God Delusion,The  Dawkins, Richard
# 90                                 "Beano" Annual,The                 0
# 91                                        White Teeth      Smith, Zadie
# 92                              House at Riverton,The      Morton, Kate
# 93                                     Book Thief,The     Zusak, Markus
# 94                           Nights of Rain and Stars     Binchy, Maeve
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume_Sold           Publisher                        genre
# 0    5,094,805          Transworld  Crime, Thriller & Adventure
# 1    4,475,152          Bloomsbury           Children's Fiction
# 2    4,200,654          Bloomsbury           Children's Fiction
# 3    4,179,479          Bloomsbury           Children's Fiction
# 4    3,758,936        Random House              Romance & Sagas
# 5    3,583,215          Bloomsbury           Children's Fiction
# 6    3,484,047          Bloomsbury           Children's Fiction
# 7    3,377,906          Bloomsbury           Children's Fiction
# 8    3,193,946          Transworld  Crime, Thriller & Adventure
# 9    2,950,264          Bloomsbury           Children's Fiction
# 10   2,479,784        Random House              Romance & Sagas
# 11   2,315,405  Little, Brown Book          Young Adult Fiction
# 12   2,233,570             Quercus  Crime, Thriller & Adventure
# 13   2,193,928        Random House              Romance & Sagas
# 14   2,183,031          Transworld  Crime, Thriller & Adventure
# 15   2,152,737  Little, Brown Book          Young Adult Fiction
# 16   2,062,145          Transworld  Crime, Thriller & Adventure
# 17   2,052,876  Little, Brown Book          Young Adult Fiction
# 18   2,005,598       Pan Macmillan   General & Literary Fiction
# 19   1,979,552        Random House   General & Literary Fiction
# 20   1,928,900          Transworld  Crime, Thriller & Adventure
# 21   1,852,919          Transworld              Popular Science
# 22   1,814,784             Quercus  Crime, Thriller & Adventure
# 23   1,787,118  Little, Brown Book          Young Adult Fiction
# 24   1,783,535             Penguin                Picture Books
# 25   1,781,269       Pan Macmillan                Picture Books
# 26   1,743,266             Penguin        Food & Drink: General
# 27   1,629,119          Bloomsbury   General & Literary Fiction
# 28   1,616,068  Hodder & Stoughton   General & Literary Fiction
# 29   1,583,992          Bloomsbury   General & Literary Fiction
# ..         ...                 ...                          ...
# 70     963,353             Penguin     Current Affairs & Issues
# 71     962,515            Headline  Crime, Thriller & Adventure
# 72     959,496  Little, Brown Book      Autobiography: The Arts
# 73     956,114       HarperCollins   General & Literary Fiction
# 74     945,640          Transworld      Autobiography: The Arts
# 75     931,312          Transworld               Travel Writing
# 76     925,425             Penguin        Food & Drink: General
# 77     924,695       Pan Macmillan   General & Literary Fiction
# 78     906,968             Penguin  National & Regional Cuisine
# 79     905,086          Transworld               Fitness & Diet
# 80     890,847          Transworld               Travel Writing
# 81     869,671        Random House  Crime, Thriller & Adventure
# 82     869,659            Headline   General & Literary Fiction
# 83     862,602        Random House        Food & Drink: General
# 84     856,540          Transworld   General & Literary Fiction
# 85     845,858             Penguin   General & Literary Fiction
# 86     842,535       Pan Macmillan                Picture Books
# 87     828,215             Penguin   General & Literary Fiction
# 88     820,563  Hodder & Stoughton      Autobiography: The Arts
# 89     816,907          Transworld              Popular Science
# 90     816,585        D.C. Thomson           Children's Annuals
# 91     815,586             Penguin   General & Literary Fiction
# 92     814,370       Pan Macmillan   General & Literary Fiction
# 93     809,641          Transworld   General & Literary Fiction
# 94     808,900               Orion   General & Literary Fiction
# 95     807,311        Random House   General & Literary Fiction
# 96     794,201             Penguin        Food & Drink: General
# 97     792,187     Scholastic Ltd.          Young Adult Fiction
# 98     791,507               Orion           Biography: General
# 99     791,095             Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %%
driver.close()

# %% [markdown]
# ## Q9

# %%
driver=webdriver.Chrome(r"C:\\Users\\p.c\\Desktop\\New folder\\chromedriver.exe")
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
name=[]
yearSpan=[]
genre=[]
runTime=[]
ratings=[]
votes=[]
try:
    nameTag=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
    name.extend([i.text for i in nameTag])
except:
    name.append("-")

try:
    yearSpantag=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
    yearSpan.extend([i.text for i in yearSpantag])
except:
    yearSpan.append("-")
    

try:
    genreTag=driver.find_elements_by_xpath("//span[@class='genre']")
    genre.extend([i.text for i in genreTag])
except:
    genre.append("-")
    
try:
    runTimeTag=driver.find_elements_by_xpath("//span[@class='runtime']")
    runTime.extend([i.text for i in runTimeTag])
except:
    runTime.append("-")
    
try:
    ratingsTag=driver.find_elements_by_xpath("//span[@class='ipl-rating-star__rating']")
    ratings.extend([i.text for i in ratingsTag[::23]])
except:
    ratings.append("-")
    
try:
    votesTag=driver.find_elements_by_xpath("//span[@name='nv']")
    votes.extend([i.text for i in votesTag])
except:
    votes.append("-")

# %%
name
# Out:
# ['Game of Thrones',
#  'Stranger Things',
#  'The Walking Dead',
#  '13 Reasons Why',
#  'The 100',
#  'Orange Is the New Black',
#  'Riverdale',
#  "Grey's Anatomy",
#  'The Flash',
#  'Arrow',
#  'Money Heist',
#  'The Big Bang Theory',
#  'Black Mirror',
#  'Sherlock',
#  'Vikings',
#  'Pretty Little Liars',
#  'The Vampire Diaries',
#  'American Horror Story',
#  'Breaking Bad',
#  'Lucifer',
#  'Supernatural',
#  'Prison Break',
#  'How to Get Away with Murder',
#  'Teen Wolf',
#  'The Simpsons',
#  'Once Upon a Time',
#  'Narcos',
#  'Daredevil',
#  'Friends',
#  'How I Met Your Mother',
#  'Suits',
#  'Mr. Robot',
#  'The Originals',
#  'Supergirl',
#  'Gossip Girl',
#  'Sense8',
#  'Gotham',
#  'Westworld',
#  'Jessica Jones',
#  'Modern Family',
#  'Rick and Morty',
#  'Shadowhunters',
#  'The End of the F***ing World',
#  'House of Cards',
#  'Dark',
#  'Elite',
#  'Sex Education',
#  'Shameless',
#  'New Girl',
#  'Agents of S.H.I.E.L.D.',
#  'You',
#  'Dexter',
#  'Fear the Walking Dead',
#  'Family Guy',
#  'The Blacklist',
#  'Lost',
#  'Peaky Blinders',
#  'House',
#  'Quantico',
#  'Orphan Black',
#  'Homeland',
#  'Blindspot',
#  "DC's Legends of Tomorrow",
#  "The Handmaid's Tale",
#  'Chilling Adventures of Sabrina',
#  'The Good Doctor',
#  'Jane the Virgin',
#  'Glee',
#  'South Park',
#  'Brooklyn Nine-Nine',
#  'Under the Dome',
#  'The Umbrella Academy',
#  'True Detective',
#  'The OA',
#  'Desperate Housewives',
#  'Better Call Saul',
#  'Bates Motel',
#  'The Punisher',
#  'Atypical',
#  'Dynasty',
#  'This Is Us',
#  'The Good Place',
#  'Iron Fist',
#  'The Rain',
#  'Mindhunter',
#  'Revenge',
#  'Luke Cage',
#  'Scandal',
#  'The Defenders',
#  'Big Little Lies',
#  'Insatiable',
#  'The Mentalist',
#  'The Crown',
#  'Chernobyl',
#  'iZombie',
#  'Reign',
#  'A Series of Unfortunate Events',
#  'Criminal Minds',
#  'Scream: The TV Series',
#  'The Haunting of Hill House']

# %%
df=pd.DataFrame()
df['Name']=name
df['yearSpan']=yearSpan
df['ratings']=ratings
df['runTime']=runTime
df['genre']=genre
df['votes']=votes
df
# Out:
#                               Name     yearSpan ratings  runTime  \
# 0                  Game of Thrones  (2011–2019)     9.2   57 min
# 1                  Stranger Things     (2016– )     8.7   51 min
# 2                 The Walking Dead  (2010–2022)     8.2   44 min
# 3                   13 Reasons Why  (2017–2020)     7.5   60 min
# 4                          The 100  (2014–2020)     7.6   43 min
# 5          Orange Is the New Black  (2013–2019)       8   59 min
# 6                        Riverdale     (2017– )     6.7   45 min
# 7                   Grey's Anatomy     (2005– )     7.5   41 min
# 8                        The Flash     (2014– )     7.6   43 min
# 9                            Arrow  (2012–2020)     7.5   42 min
# 10                     Money Heist  (2017–2021)     8.2   70 min
# 11             The Big Bang Theory  (2007–2019)     8.1   22 min
# 12                    Black Mirror  (2011–2019)     8.8   60 min
# 13                        Sherlock  (2010–2017)     9.1   88 min
# 14                         Vikings  (2013–2020)     8.5   44 min
# 15             Pretty Little Liars  (2010–2017)     7.4   44 min
# 16             The Vampire Diaries  (2009–2017)     7.7   43 min
# 17           American Horror Story     (2011– )       8   60 min
# 18                    Breaking Bad  (2008–2013)     9.4   49 min
# 19                         Lucifer  (2016–2021)     8.1   42 min
# 20                    Supernatural  (2005–2020)     8.4   44 min
# 21                    Prison Break  (2005–2017)     8.3   44 min
# 22     How to Get Away with Murder  (2014–2020)     8.1   43 min
# 23                       Teen Wolf  (2011–2017)     7.6   41 min
# 24                    The Simpsons     (1989– )     8.6   22 min
# 25                Once Upon a Time  (2011–2018)     7.7   60 min
# 26                          Narcos  (2015–2017)     8.8   49 min
# 27                       Daredevil  (2015–2018)     8.6   54 min
# 28                         Friends  (1994–2004)     8.8   22 min
# 29           How I Met Your Mother  (2005–2014)     8.3   22 min
# ..                             ...          ...     ...      ...
# 70                  Under the Dome  (2013–2015)     6.6   43 min
# 71            The Umbrella Academy     (2019– )       8   60 min
# 72                  True Detective  (2014–2019)     8.9   55 min
# 73                          The OA  (2016–2019)     7.8   60 min
# 74            Desperate Housewives  (2004–2012)     7.5   45 min
# 75                Better Call Saul  (2015–2022)     8.8   46 min
# 76                     Bates Motel  (2013–2017)     8.1   45 min
# 77                    The Punisher  (2017–2019)     8.5   53 min
# 78                        Atypical  (2017–2021)     8.3   30 min
# 79                         Dynasty     (2017– )     7.3   42 min
# 80                      This Is Us  (2016–2022)     8.6   45 min
# 81                  The Good Place  (2016–2020)     8.2   22 min
# 82                       Iron Fist  (2017–2018)     6.4   55 min
# 83                        The Rain  (2018–2020)     6.3   45 min
# 84                      Mindhunter  (2017–2019)     8.6   60 min
# 85                         Revenge  (2011–2015)     7.8   44 min
# 86                       Luke Cage  (2016–2018)     7.3   55 min
# 87                         Scandal  (2012–2018)     7.7   43 min
# 88                   The Defenders       (2017)     7.3   50 min
# 89                 Big Little Lies  (2017–2019)     8.5   60 min
# 90                      Insatiable  (2018–2019)     6.5   45 min
# 91                   The Mentalist  (2008–2015)     8.1   43 min
# 92                       The Crown     (2016– )     8.6   58 min
# 93                       Chernobyl       (2019)     9.4  330 min
# 94                         iZombie  (2015–2019)     7.8   42 min
# 95                           Reign  (2013–2017)     7.5   42 min
# 96  A Series of Unfortunate Events  (2017–2019)     7.8   50 min
# 97                  Criminal Minds  (2005–2020)     8.1   42 min
# 98           Scream: The TV Series  (2015–2019)     7.1   45 min
# 99      The Haunting of Hill House       (2018)     8.6  572 min
#
#                           genre      votes
# 0      Action, Adventure, Drama  1,927,443
# 1        Drama, Fantasy, Horror    949,642
# 2       Drama, Horror, Thriller    921,167
# 3      Drama, Mystery, Thriller    275,950
# 4        Drama, Mystery, Sci-Fi    236,230
# 5          Comedy, Crime, Drama    290,849
# 6         Crime, Drama, Mystery    135,375
# 7                Drama, Romance    283,943
# 8      Action, Adventure, Drama    331,056
# 9      Action, Adventure, Crime    421,426
# 10         Action, Crime, Drama    434,519
# 11              Comedy, Romance    766,488
# 12      Drama, Sci-Fi, Thriller    496,935
# 13        Crime, Drama, Mystery    868,967
# 14     Action, Adventure, Drama    485,307
# 15      Drama, Mystery, Romance    160,234
# 16       Drama, Fantasy, Horror    303,993
# 17      Drama, Horror, Thriller    302,783
# 18       Crime, Drama, Thriller  1,634,023
# 19        Crime, Drama, Fantasy    300,104
# 20       Drama, Fantasy, Horror    418,190
# 21         Action, Crime, Drama    506,871
# 22        Crime, Drama, Mystery    142,558
# 23       Action, Drama, Fantasy    138,893
# 24     Animation, Short, Comedy    387,466
# 25  Adventure, Fantasy, Romance    217,222
# 26      Biography, Crime, Drama    393,184
# 27         Action, Crime, Drama    397,053
# 28              Comedy, Romance    924,554
# 29              Comedy, Romance    646,422
# ..                          ...        ...
# 70       Drama, Mystery, Sci-Fi    104,279
# 71    Action, Adventure, Comedy    191,334
# 72        Crime, Drama, Mystery    532,668
# 73      Drama, Fantasy, Mystery     99,130
# 74       Comedy, Drama, Mystery    123,552
# 75                 Crime, Drama    371,548
# 76       Drama, Horror, Mystery    103,518
# 77         Action, Crime, Drama    208,224
# 78                Comedy, Drama     80,066
# 79                        Drama     20,060
# 80       Comedy, Drama, Romance    122,632
# 81       Comedy, Drama, Fantasy    139,301
# 82     Action, Adventure, Crime    123,556
# 83      Drama, Sci-Fi, Thriller     34,631
# 84       Crime, Drama, Thriller    255,153
# 85     Drama, Mystery, Thriller    117,229
# 86         Action, Crime, Drama    124,179
# 87              Drama, Thriller     70,807
# 88     Action, Adventure, Crime     99,050
# 89        Crime, Drama, Mystery    180,814
# 90      Comedy, Drama, Thriller     26,024
# 91        Crime, Drama, Mystery    174,881
# 92    Biography, Drama, History    183,064
# 93     Drama, History, Thriller    640,786
# 94         Comedy, Crime, Drama     64,799
# 95               Drama, Fantasy     47,101
# 96     Adventure, Comedy, Drama     57,887
# 97        Crime, Drama, Mystery    182,752
# 98         Comedy, Crime, Drama     38,196
# 99       Drama, Horror, Mystery    217,519
#
# [100 rows x 6 columns]

# %% [markdown]
# ## Q10

# %%
driver.get("https://archive.ics.uci.edu/")

# %%
driver.get(driver.find_elements_by_xpath("//span[@class='normal']/b/a")[0].get_attribute('href'))

# %%
ten=[]
try:
    tag=driver.find_elements_by_xpath("//td//p[@class='normal']")
    ten.extend([i.text for i in tag[8:4362]])
except:
    ten.append('-')

# %%
len(ten)
# Out:
# 4354

# %%
dtset=ten[::7]
dtype=ten[1::7]
task=ten[2::7]
attTypeType=ten[3::7]
no_instances=ten[4::7]
no_att=ten[5::7]
year=ten[6::7]

# %%
df=pd.DataFrame()
df['datasetName']=ten[::7]
df['dataTypes']=ten[1::7]
df['task']=ten[2::7]
df['AttributrType']=ten[3::7]
df['noOfInstances']=ten[4::7]
df['noOFAttribute']=ten[5::7]
df['year']=ten[6::7]
df
# Out:
#                                            datasetName  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# 5                                Artificial Characters
# 6                                 Audiology (Original)
# 7                             Audiology (Standardized)
# 8                                             Auto MPG
# 9                                           Automobile
# 10                                              Badges
# 11                                       Balance Scale
# 12                                            Balloons
# 13                                       Breast Cancer
# 14                  Breast Cancer Wisconsin (Original)
# 15                Breast Cancer Wisconsin (Prognostic)
# 16                Breast Cancer Wisconsin (Diagnostic)
# 17                                  Pittsburgh Bridges
# 18                                      Car Evaluation
# 19                                       Census Income
# 20                   Chess (King-Rook vs. King-Knight)
# 21                     Chess (King-Rook vs. King-Pawn)
# 22                          Chess (King-Rook vs. King)
# 23                             Chess (Domain Theories)
# 24                                       Bach Chorales
# 25                                           Connect-4
# 26                                     Credit Approval
# 27                           Japanese Credit Screening
# 28                                   Computer Hardware
# 29                         Contraceptive Method Choice
# ..                                                 ...
# 592                       Synchronous Machine Data Set
# 593                        Pedal Me Bicycle Deliveries
# 594                          Turkish Headlines Dataset
# 595                         Secondary Mushroom Dataset
# 596                  Power consumption of Tetouan city
# 597                                     Raisin Dataset
# 598          Steel Industry Energy Consumption Dataset
# 599                           Gender Gap in Spanish WP
# 600                           Non verbal tourists data
# 601      Roman Urdu Sentiment Analysis Dataset (RUSAD)
# 602  TUANDROMD ( Tezpur University Android Malware ...
# 603  Higher Education Students Performance Evaluati...
# 604   Risk Factor prediction of Chronic Kidney Disease
# 605                                           Lab Test
# 606        Shoulder Implant Manufacture Classification
# 607                  Rocket League Skillshots Data Set
# 608           Sepsis survival minimal clinical records
# 609                           Water Quality Prediction
# 610                           Traffic Flow Forecasting
# 611  sentiment analysis in Saudi Arabia about dista...
# 612                            Kain Tradisional Sambas
# 613  Image Recognition Task Execution Times in Mobi...
# 614                                             REWEMA
# 615                                           REJAFADA
# 616          Steel Industry Energy Consumption Dataset
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                                 dataTypes  \
# 0                           Multivariate
# 1                           Multivariate
# 2                           Multivariate
# 3
# 4                           Multivariate
# 5                           Multivariate
# 6                           Multivariate
# 7                           Multivariate
# 8                           Multivariate
# 9                           Multivariate
# 10                      Univariate, Text
# 11                          Multivariate
# 12                          Multivariate
# 13                          Multivariate
# 14                          Multivariate
# 15                          Multivariate
# 16                          Multivariate
# 17                          Multivariate
# 18                          Multivariate
# 19                          Multivariate
# 20          Multivariate, Data-Generator
# 21                          Multivariate
# 22                          Multivariate
# 23                         Domain-Theory
# 24               Univariate, Time-Series
# 25                 Multivariate, Spatial
# 26                          Multivariate
# 27           Multivariate, Domain-Theory
# 28                          Multivariate
# 29                          Multivariate
# ..                                    ...
# 592                         Multivariate
# 593                          Time-Series
# 594                                 Text
# 595                           Univariate
# 596            Multivariate, Time-Series
# 597                         Multivariate
# 598                         Multivariate
# 599                         Multivariate
# 600                         Multivariate
# 601                                 Text
# 602                         Multivariate
# 603                         Multivariate
# 604                         Multivariate
# 605                         Multivariate
# 606                         Multivariate
# 607            Multivariate, Time-Series
# 608                         Multivariate
# 609                         Multivariate
# 610                         Multivariate
# 611                                 Text
# 612                         Multivariate
# 613  Univariate, Sequential, Time-Series
# 614                         Multivariate
# 615                         Multivariate
# 616                         Multivariate
# 617                         Multivariate
# 618                         Multivariate
# 619
# 620            Multivariate, Time-Series
# 621                           Univariate
#
#                                         task                AttributrType  \
# 0                            Classification   Categorical, Integer, Real
# 1                            Classification         Categorical, Integer
# 2                            Classification   Categorical, Integer, Real
# 3                       Recommender-Systems                  Categorical
# 4                            Classification   Categorical, Integer, Real
# 5                            Classification   Categorical, Integer, Real
# 6                            Classification                  Categorical
# 7                            Classification                  Categorical
# 8                                Regression            Categorical, Real
# 9                                Regression   Categorical, Integer, Real
# 10                           Classification
# 11                           Classification                  Categorical
# 12                           Classification                  Categorical
# 13                           Classification                  Categorical
# 14                           Classification                      Integer
# 15               Classification, Regression                         Real
# 16                           Classification                         Real
# 17                           Classification         Categorical, Integer
# 18                           Classification                  Categorical
# 19                           Classification         Categorical, Integer
# 20                           Classification         Categorical, Integer
# 21                           Classification                  Categorical
# 22                           Classification         Categorical, Integer
# 23
# 24                                                  Categorical, Integer
# 25                           Classification                  Categorical
# 26                           Classification   Categorical, Integer, Real
# 27                           Classification   Categorical, Real, Integer
# 28                               Regression                      Integer
# 29                           Classification         Categorical, Integer
# ..                                       ...                          ...
# 592                              Regression                         Real
# 593                              Regression                         Real
# 594              Classification, Clustering
# 595                          Classification                         Real
# 596                              Regression                Integer, Real
# 597                          Classification                Integer, Real
# 598                              Regression
# 599                          Classification                Integer, Real
# 600              Classification, Clustering                Integer, Real
# 601                          Classification
# 602                          Classification                      Integer
# 603                          Classification                      Integer
# 604              Classification, Regression                         Real
# 605  Classification, Regression, Clustering
# 606                          Classification
# 607                          Classification                         Real
# 608                          Classification                      Integer
# 609                              Regression                         Real
# 610                              Regression                         Real
# 611                          Classification                      Integer
# 612              Classification, Clustering
# 613                              Regression                         Real
# 614                          Classification                      Integer
# 615                          Classification                      Integer
# 616                              Regression                      Integer
# 617                          Classification                Integer, Real
# 618                          Classification                Integer, Real
# 619                          Classification
# 620                          Classification                         Real
# 621                              Regression                         Real
#
#     noOfInstances noOFAttribute   year
# 0           4177             8   1995
# 1          48842            14   1996
# 2            798            38
# 3          37711           294   1998
# 4            452           279   1998
# 5           6000             7   1992
# 6            226                 1987
# 7            226            69   1992
# 8            398             8   1993
# 9            205            26   1987
# 10           294             1   1994
# 11           625             4   1994
# 12            16             4
# 13           286             9   1988
# 14           699            10   1992
# 15           198            34   1995
# 16           569            32   1995
# 17           108            13   1990
# 18          1728             6   1997
# 19         48842            14   1996
# 20                          22   1988
# 21          3196            36   1989
# 22         28056             6   1994
# 23
# 24           100             6
# 25         67557            42   1995
# 26           690            15
# 27           125                 1992
# 28           209             9   1987
# 29          1473             9   1997
# ..            ...           ...    ...
# 592          557             5   2021
# 593           36            15   2021
# 594         4200             7   2021
# 595        61069            21   2021
# 596        52417             9   2021
# 597          900             8   2021
# 598        35040            11   2021
# 599         4746            21   2021
# 600           73            22   2021
# 601        11000             2   2021
# 602         4465           241   2021
# 603          145            33   2021
# 604          202            29   2021
# 605          221             7   2021
# 606          597             1   2020
# 607          298                 2020
# 608       110341             4   2020
# 609          705            11   2020
# 610         2101            47   2020
# 611         1765            10   2020
# 612          150             3   2020
# 613         4000             2   2020
# 614         6272           632   2020
# 615         1996          6826   2020
# 616        35040            11   2020
# 617        75840           525   2020
# 618          400            50   2020
# 619         1014             7   2020
# 620        10129            16   2021
# 621         4000             2   2021
#
# [622 rows x 7 columns]

# %%
driver.close()
