# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,BaggingRegressor,AdaBoostRegressor
from sklearn.linear_model import LinearRegression,LassoCV,Lasso
from sklearn.neighbors import KNeighborsRegressor

from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.preprocessing import LabelEncoder,PowerTransformer,StandardScaler
from scipy.stats import zscore
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel("Flight_scrapped_data.xlsx")
df
# Out:
#       Unnamed: 0 AirlineName         Date     Source Destination  \
# 0              0    SpiceJet   6 Apr 2022  New Delhi      Mumbai
# 1              1    SpiceJet   6 Apr 2022  New Delhi      Mumbai
# 2              2    SpiceJet   6 Apr 2022  New Delhi      Mumbai
# 3              3    SpiceJet   6 Apr 2022  New Delhi      Mumbai
# 4              4    SpiceJet   6 Apr 2022  New Delhi      Mumbai
# ...          ...         ...          ...        ...         ...
# 1887        2550   Air India  22 Apr 2022      Patna   Bangalore
# 1888        2551   Air India  22 Apr 2022      Patna   Bangalore
# 1889        2552     Vistara  22 Apr 2022      Patna   Bangalore
# 1890        2554     Vistara  22 Apr 2022      Patna   Bangalore
# 1891        2555     Vistara  22 Apr 2022      Patna   Bangalore
#
#      DepartureTime ArrivalTime Duration Total_Stops  Price
# 0            07:20       09:35   2h 15m         Non   7318
# 1            18:55       21:10   2h 15m         Non   7318
# 2            19:45       22:00   2h 15m         Non   7318
# 3            06:20       08:45   2h 25m         Non   7318
# 4            05:45       17:50  12h 05m           1   7318
# ...            ...         ...      ...         ...    ...
# 1887         16:00       07:50  15h 50m           2  14232
# 1888         16:00       11:10  19h 10m           2  14232
# 1889         10:00       19:15   9h 15m           2  15387
# 1890         10:00       20:55  10h 55m           2  15387
# 1891         10:00       17:45   7h 45m           2  15912
#
# [1892 rows x 10 columns]

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.head()
# Out:
#   AirlineName        Date     Source Destination DepartureTime ArrivalTime  \
# 0    SpiceJet  6 Apr 2022  New Delhi      Mumbai         07:20       09:35
# 1    SpiceJet  6 Apr 2022  New Delhi      Mumbai         18:55       21:10
# 2    SpiceJet  6 Apr 2022  New Delhi      Mumbai         19:45       22:00
# 3    SpiceJet  6 Apr 2022  New Delhi      Mumbai         06:20       08:45
# 4    SpiceJet  6 Apr 2022  New Delhi      Mumbai         05:45       17:50
#
#   Duration Total_Stops  Price
# 0   2h 15m         Non   7318
# 1   2h 15m         Non   7318
# 2   2h 15m         Non   7318
# 3   2h 25m         Non   7318
# 4  12h 05m           1   7318

# %%
df['Total_Stops']=df['Total_Stops'].replace("Non",0)

# %%
df['Total_Stops']=df['Total_Stops'].astype(int)
df['Price']=df['Price'].astype(int)

# %%
df['Duration']=pd.to_timedelta(df.Duration)
df['Duration_hours']=df.Duration.dt.total_seconds()//3600

# %%
df['Date']=pd.to_datetime(df.Date, format="%d %b %Y")

# %%
df.head()
# Out:
#   AirlineName       Date     Source Destination DepartureTime ArrivalTime  \
# 0    SpiceJet 2022-04-06  New Delhi      Mumbai         07:20       09:35
# 1    SpiceJet 2022-04-06  New Delhi      Mumbai         18:55       21:10
# 2    SpiceJet 2022-04-06  New Delhi      Mumbai         19:45       22:00
# 3    SpiceJet 2022-04-06  New Delhi      Mumbai         06:20       08:45
# 4    SpiceJet 2022-04-06  New Delhi      Mumbai         05:45       17:50
#
#          Duration  Total_Stops  Price  Duration_hours
# 0 0 days 02:15:00            0   7318             2.0
# 1 0 days 02:15:00            0   7318             2.0
# 2 0 days 02:15:00            0   7318             2.0
# 3 0 days 02:25:00            0   7318             2.0
# 4 0 days 12:05:00            1   7318            12.0

# %%
## Transforming New columns for DateOfJourney,Dep_time,Arrival_Time,Duration

df['Journey_day']= df["Date"].dt.day
#Two new features transformed through DataOfJourney


df["Dep_hour"]= pd.to_datetime(df['DepartureTime']).dt.hour


#Two new features transformed through Dep_Time.


df["Arr_hour"]= pd.to_datetime(df['ArrivalTime']).dt.hour

#Two new features transformed through Arrival_Time as tihis column is also transformed.


df.head(2)
# Out:
#   AirlineName       Date     Source Destination DepartureTime ArrivalTime  \
# 0    SpiceJet 2022-04-06  New Delhi      Mumbai         07:20       09:35
# 1    SpiceJet 2022-04-06  New Delhi      Mumbai         18:55       21:10
#
#          Duration  Total_Stops  Price  Duration_hours  Journey_day  Dep_hour  \
# 0 0 days 02:15:00            0   7318             2.0            6         7
# 1 0 days 02:15:00            0   7318             2.0            6        18
#
#    Arr_hour
# 0         9
# 1        21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1892 entries, 0 to 1891
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AirlineName     1892 non-null   object
#  1   Date            1892 non-null   datetime64[ns]
#  2   Source          1892 non-null   object
#  3   Destination     1892 non-null   object
#  4   DepartureTime   1892 non-null   object
#  5   ArrivalTime     1892 non-null   object
#  6   Duration        1892 non-null   timedelta64[ns]
#  7   Total_Stops     1892 non-null   int32
#  8   Price           1892 non-null   int32
#  9   Duration_hours  1892 non-null   float64
#  10  Journey_day     1892 non-null   int64
#  11  Dep_hour        1892 non-null   int64
#  12  Arr_hour        1892 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int32(2), int64(3), object(5), timedelta64[ns](1)
# memory usage: 177.5+ KB

# %%
df.shape
# Out:
# (1892, 13)

# %%
df.isna().sum()
# Out:
# AirlineName       0
# Date              0
# Source            0
# Destination       0
# DepartureTime     0
# ArrivalTime       0
# Duration          0
# Total_Stops       0
# Price             0
# Duration_hours    0
# Journey_day       0
# Dep_hour          0
# Arr_hour          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['AirlineName', 'Date', 'Source', 'Destination', 'DepartureTime',
#        'ArrivalTime', 'Duration', 'Total_Stops', 'Price', 'Duration_hours',
#        'Journey_day', 'Dep_hour', 'Arr_hour'],
#       dtype='object')

# %% [markdown]
# AirlineName: The name of the airline.
#
# Date: The date of the journey
#
# Source: The source from which the service begins.
#
# Destination: The destination where the service ends.
#
# DepartureTime: The time when the journey starts from the source.
#
# ArrivalTime: Time of arrival at the destination.
#
# Duration: Total duration of the flight.
#
# Total_Stops: Total stops between the source and destination.
#
# Price: The price of the ticket

# %%
df.describe()
# Out:
#                         Duration  Total_Stops         Price  Duration_hours  \
# count                       1892  1892.000000   1892.000000     1892.000000
# mean   0 days 09:56:06.437632135     0.949260   8972.396406        9.485201
# std    0 days 08:14:59.390414696     0.728337   3739.265532        8.246038
# min              0 days 01:00:00     0.000000   3601.000000        1.000000
# 25%              0 days 02:50:00     0.000000   6291.000000        2.000000
# 50%              0 days 07:20:00     1.000000   7986.000000        7.000000
# 75%              0 days 14:15:00     1.000000  10721.000000       14.000000
# max              1 days 17:30:00     3.000000  26411.000000       41.000000
#
#        Journey_day     Dep_hour     Arr_hour
# count  1892.000000  1892.000000  1892.000000
# mean     17.671776    12.822410    13.529598
# std       5.489434     5.778584     6.503115
# min       6.000000     0.000000     0.000000
# 25%      15.000000     7.000000     9.000000
# 50%      18.000000    13.000000    14.000000
# 75%      22.000000    18.000000    19.000000
# max      28.000000    23.000000    23.000000

# %%
plt.figure(figsize=(15,5))
df.groupby("Dep_hour")['Price'].mean().plot(kind='line')
plt.show()

# %% [markdown]
# Morning flights are less expensive in comparision to others flights.

# %%
plt.figure(figsize=(15,5))
df.groupby("Arr_hour")['Price'].mean().plot(kind='line')
plt.show()

# %%
sns.barplot(df['Price'],df['AirlineName'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='AirlineName'>

# %% [markdown]
# `Indigo` flights are less expensive in comparision to `Spicejet`.
#
# `Vistura` flights are most expensive.

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x=df['Date'],y=df['Price'])
plt.show()

# %% [markdown]
# Flights fares are incresing as the departure date of the flihts is getting closed. The fares increments over time is with some up and downs.

# %%
plt.figure(figsize=(5,5))
df.groupby("Total_Stops")['Price'].mean().plot(kind='bar',color='darkseagreen')
plt.show()

# %% [markdown]
# As No. of stops increments for the consumer to reach its destination with cost him expensive.

# %%
plt.figure(figsize=(10,5))
df.groupby("Duration_hours")['Price'].mean().plot(kind='line',color='darkseagreen')
plt.show()

# %% [markdown]
# The Customer spends more time in flights cost him expensive to reach the destination.

# %%
plt.figure(figsize=(20,5))
k=df.groupby(["Source","Destination"])['Price'].sort().plot(kind='bar',color='purple')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Mumbai To Varanasi flights are most Expensive.

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(df['Duration_hours'],df['Price'],hue=df['Total_Stops'])
plt.show()

# %% [markdown]
# As the no of stops increasing slowly the price and duration increasing.

# %%
sns.countplot(df['Total_Stops'])
# Out:
# <AxesSubplot:xlabel='Total_Stops', ylabel='count'>

# %% [markdown]
# We have to remove records for 3 no. of stopage because no much data we have for 3 Stopage. That will made our model under fit.

# %%
df.columns
# Out:
# Index(['AirlineName', 'Date', 'Source', 'Destination', 'DepartureTime',
#        'ArrivalTime', 'Duration', 'Total_Stops', 'Price', 'Duration_hours',
#        'Journey_day', 'Dep_hour', 'Arr_hour'],
#       dtype='object')

# %%
#Remove date as we have same month and year data so we just need journey_day instead od date.
#Removing DepartureTime,ArrivalTime as we the hour timimg of the flights departured and alighting.
#Duration also to be removed as we transformed duration_hours .

# %% [markdown]
# #### Data Cleaning

# %%
df.drop(columns=["Date","DepartureTime","ArrivalTime","Duration"], inplace=True)

# %%
df.columns
# Out:
# Index(['AirlineName', 'Source', 'Destination', 'Total_Stops', 'Price',
#        'Duration_hours', 'Journey_day', 'Dep_hour', 'Arr_hour'],
#       dtype='object')

# %%
categorical_var=['AirlineName', 'Source', 'Destination']
encoder=LabelEncoder()
for i in categorical_var:
    df[i]=encoder.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1892 entries, 0 to 1891
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   AirlineName     1892 non-null   int32
#  1   Source          1892 non-null   int32
#  2   Destination     1892 non-null   int32
#  3   Total_Stops     1892 non-null   int32
#  4   Price           1892 non-null   int32
#  5   Duration_hours  1892 non-null   float64
#  6   Journey_day     1892 non-null   int64
#  7   Dep_hour        1892 non-null   int64
#  8   Arr_hour        1892 non-null   int64
# dtypes: float64(1), int32(5), int64(3)
# memory usage: 96.2 KB

# %%
plt.figure(figsize=(8,5))
plotno=1
for col in df.drop("Price",axis=1):
    if plotno<=8:
        ax=plt.subplot(4,2,plotno)
        sns.boxplot(df[col],orient='v')
        plt.xlabel(col,fontsize=20)
    plotno+=1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
plt.show()

# %%
plt.figure(figsize=(10,5))
plotno=1
for col in df.drop("Price",axis=1):
    if plotno<=12:
        ax=plt.subplot(2,4,plotno)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize=15)
    plotno+=1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
plt.show()

# %%
df.skew()
# Out:
# AirlineName      -0.196737
# Source           -0.173553
# Destination       0.014322
# Total_Stops       0.201335
# Price             0.927690
# Duration_hours    1.147638
# Journey_day      -0.697395
# Dep_hour         -0.003561
# Arr_hour         -0.463232
# dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr().abs(),annot=True,annot_kws={"size":15},linewidths=True)
plt.show()

# %%
df.drop(['Price'],axis=1).corrwith(df.Price).plot(kind='bar',grid=True)
# Out:
# <AxesSubplot:>

# %%
## Removing Outliers from dataset.

Zscore=zscore(df[["Duration_hours","Total_Stops"]])
abs_Zscore=np.abs(Zscore)
filtered=(abs_Zscore<3).all(axis=1)
df=df[filtered]

# %%
df.shape
# Out:
# (1882, 9)

# %%
plt.figure(figsize=(8,5))
plotno=1
for col in df.drop("Price",axis=1):
    if plotno<=8:
        ax=plt.subplot(4,2,plotno)
        sns.boxplot(df[col],orient='v')
        plt.xlabel(col,fontsize=20)
    plotno+=1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
plt.show()

# %%
df.skew()
# Out:
# AirlineName      -0.201470
# Source           -0.176467
# Destination       0.010573
# Total_Stops       0.211152
# Price             0.946747
# Duration_hours    1.077059
# Journey_day      -0.690451
# Dep_hour         -0.011259
# Arr_hour         -0.462625
# dtype: float64

# %%
df.describe()
# Out:
#        AirlineName       Source  Destination  Total_Stops         Price  \
# count  1882.000000  1882.000000  1882.000000  1882.000000   1882.000000
# mean      3.775239     2.821998     3.156217     0.943677   8944.626461
# std       2.360620     1.785310     2.651680     0.726220   3729.171883
# min       0.000000     0.000000     0.000000     0.000000   3601.000000
# 25%       1.000000     2.000000     0.000000     0.000000   6291.000000
# 50%       4.000000     3.000000     3.000000     1.000000   7974.000000
# 75%       5.000000     4.000000     6.000000     1.000000  10583.250000
# max       7.000000     6.000000     7.000000     3.000000  26411.000000
#
#        Duration_hours  Journey_day     Dep_hour     Arr_hour
# count     1882.000000  1882.000000  1882.000000  1882.000000
# mean         9.334219    17.654091    12.843252    13.553135
# std          8.001155     5.497272     5.784853     6.461401
# min          1.000000     6.000000     0.000000     0.000000
# 25%          2.000000    15.000000     7.000000     9.000000
# 50%          7.000000    18.000000    13.000000    14.000000
# 75%         13.750000    22.000000    18.000000    19.000000
# max         34.000000    28.000000    23.000000    23.000000

# %%
features=['Journey_day','Duration_hours']
scalar=PowerTransformer(method='box-cox')
df[features]=scalar.fit_transform(df[features].values)
df[features].head()
# Out:
#    Journey_day  Duration_hours
# 0     -1.86774       -1.129880
# 1     -1.86774       -1.129880
# 2     -1.86774       -1.129880
# 3     -1.86774       -1.129880
# 4     -1.86774        0.653406

# %%
plt.figure(figsize=(10,5))
plotno=1
for col in df.drop("Price",axis=1):
    if plotno<=12:
        ax=plt.subplot(2,4,plotno)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize=15)
    plotno+=1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
plt.show()

# %%
df.skew()
# Out:
# AirlineName      -0.201470
# Source           -0.176467
# Destination       0.010573
# Total_Stops       0.211152
# Price             0.946747
# Duration_hours   -0.047485
# Journey_day      -0.190922
# Dep_hour         -0.011259
# Arr_hour         -0.462625
# dtype: float64

# %%
df.shape
# Out:
# (1882, 9)

# %%
##Data loss
print(f"Data Lost:{round(((1892-1882)/10683)*100,2)}%")
# Out:
# Data Lost:0.09%

# %% [markdown]
# ### Model Deployment

# %%
X=df.drop("Price",axis=1)
Y=df.Price

# %% [markdown]
# splitting data into fetures & labels.
#
# Here X is our features & Y is our label.

# %%
## Normalizing Both train &test dataset.

scalar=StandardScaler()
X_=scalar.fit_transform(X)

# %%
Linear=LinearRegression()
DecisionTree=DecisionTreeRegressor()
knn=KNeighborsRegressor()
RandomForest=RandomForestRegressor()
AdaBoost=AdaBoostRegressor()
Bagging=BaggingRegressor()
algo=[Linear,DecisionTree,Bagging,RandomForest,knn,AdaBoost]

# %%
model_acc_rs={}
maximum_acc=[]
for model in algo:
    max_accuracy=0
    for i in range(100,180,3):
        X_train,X_test,Y_train,Y_test=train_test_split(X_,Y,test_size=0.2,random_state=i)
        model.fit(X_train,Y_train)
        Y_pred=model.predict(X_test)
        accuracy=r2_score(Y_test,Y_pred)*100
        if accuracy>max_accuracy:
            max_accuracy=accuracy
            rs=i
            mae=mean_absolute_error(Y_test,Y_pred)
            mse=mean_squared_error(Y_test,Y_pred)
            rmse=np.sqrt(mean_squared_error(Y_test,Y_pred))
    maximum_acc.append(max_accuracy)
    model_acc_rs[model]=[max_accuracy,rs]
    print(f"\n\n{model}:\n---------------------------\n---------------------------\n")
    print(f"The highest accuracy is {max_accuracy} of model {model} at random state {rs}")


    print("\nMEAN ABSOLUTE ERROR:",mae)

    print(f"\nMEAN SQUARED ERROR for the model:",mse)
    
    print(f"\nROOT MEAN SQUARED ERROR for the model:",rmse)
# Out:
# LinearRegression():
# ---------------------------
# ---------------------------
#
# The highest accuracy is 73.42438274479474 of model LinearRegression() at random state 157
#
# MEAN ABSOLUTE ERROR: 1501.5124208674604
#
# MEAN SQUARED ERROR for the model: 3745058.526399985
#
# ROOT MEAN SQUARED ERROR for the model: 1935.2153695131674
#
#
# DecisionTreeRegressor():
# ---------------------------
# ---------------------------
#
# The highest accuracy is 91.80753604053344 of model DecisionTreeRegressor() at random state 175
#
# MEAN ABSOLUTE ERROR: 543.6343943412909
#
# MEAN SQUARED ERROR for the model: 1137795.736442676
#
# ROOT MEAN SQUARED ERROR for the model: 1066.6750847576202
#
#
# BaggingRegressor():
# ---------------------------
# ---------------------------
#
# The highest accuracy is 94.11519296857517 of model BaggingRegressor() at random state 178
#
# MEAN ABSOLUTE ERROR: 516.5691827712517
#
# MEAN SQUARED ERROR for the model: 737440.8194045308
#
# ROOT MEAN SQUARED ERROR for the model: 858.7437448997988
#
#
# RandomForestRegressor():
# ---------------------------
# ---------------------------
#
# The highest accuracy is 95.43556006527989 of model RandomForestRegressor() at random state 178
#
# MEAN ABSOLUTE ERROR: 452.9606935707971
#
# MEAN SQUARED ERROR for the model: 571982.1070781646
#
# ROOT MEAN SQUARED ERROR for the model: 756.2949868127943
#
#
# KNeighborsRegressor():
# ---------------------------
# ---------------------------
#
# The highest accuracy is 87.3203821854327 of model KNeighborsRegressor() at random state 175
#
# MEAN ABSOLUTE ERROR: 897.9066312997347
#
# MEAN SQUARED ERROR for the model: 1760986.0916710878
#
# ROOT MEAN SQUARED ERROR for the model: 1327.021511382196
#
#
# AdaBoostRegressor():
# ---------------------------
# ---------------------------
#
# The highest accuracy is 81.33329065759828 of model AdaBoostRegressor() at random state 157
#
# MEAN ABSOLUTE ERROR: 1289.247889340487
#
# MEAN SQUARED ERROR for the model: 2630528.5145879053
#
# ROOT MEAN SQUARED ERROR for the model: 1621.8904138652233

# %%
CVmodel={}

for model in algo:
    CVscore_={}
    print(f"\n{model}")
    print("-"*25)
    print("\n")
    for i in range(7,12):
        cvS=cross_val_score(model,X_,Y,cv=i)
        CVscore_[i]=cvS.mean()
        print(f"Mean CV Score of model {model}:: {cvS.mean()} at k-fold::{i}\n")
    CVdata=pd.DataFrame(CVscore_,index=[""])
    CVmodel[str(model)]=CVdata.max(axis=1).tolist()
# Out:
# LinearRegression()
# -------------------------
#
#
# Mean CV Score of model LinearRegression():: 0.5493906172354185 at k-fold::7
#
# Mean CV Score of model LinearRegression():: 0.530982852744496 at k-fold::8
#
# Mean CV Score of model LinearRegression():: 0.5446433640014062 at k-fold::9
#
# Mean CV Score of model LinearRegression():: 0.5658113799818976 at k-fold::10
#
# Mean CV Score of model LinearRegression():: 0.3088153589687434 at k-fold::11
#
#
# DecisionTreeRegressor()
# -------------------------
#
#
# Mean CV Score of model DecisionTreeRegressor():: 0.6123450372295031 at k-fold::7
#
# Mean CV Score of model DecisionTreeRegressor():: 0.571039504517754 at k-fold::8
#
# Mean CV Score of model DecisionTreeRegressor():: 0.577315486212323 at k-fold::9
#
# Mean CV Score of model DecisionTreeRegressor():: 0.6366544156002161 at k-fold::10
#
# Mean CV Score of model DecisionTreeRegressor():: 0.5493690610126969 at k-fold::11
#
#
# BaggingRegressor()
# -------------------------
#
#
# Mean CV Score of model BaggingRegressor():: 0.7274925105354875 at k-fold::7
#
# Mean CV Score of model BaggingRegressor():: 0.6837938589536403 at k-fold::8
#
# Mean CV Score of model BaggingRegressor():: 0.6993493262854868 at k-fold::9
#
# Mean CV Score of model BaggingRegressor():: 0.7524276913880277 at k-fold::10
#
# Mean CV Score of model BaggingRegressor():: 0.6059198493538941 at k-fold::11
#
#
# RandomForestRegressor()
# -------------------------
#
#
# Mean CV Score of model RandomForestRegressor():: 0.7359872207079675 at k-fold::7
#
# Mean CV Score of model RandomForestRegressor():: 0.704146489461496 at k-fold::8
#
# Mean CV Score of model RandomForestRegressor():: 0.7199639550511999 at k-fold::9
#
# Mean CV Score of model RandomForestRegressor():: 0.7725787083357123 at k-fold::10
#
# Mean CV Score of model RandomForestRegressor():: 0.6475666182037472 at k-fold::11
#
#
# KNeighborsRegressor()
# -------------------------
#
#
# Mean CV Score of model KNeighborsRegressor():: 0.606211277894095 at k-fold::7
#
# Mean CV Score of model KNeighborsRegressor():: 0.5583786477423041 at k-fold::8
#
# Mean CV Score of model KNeighborsRegressor():: 0.5890692844202223 at k-fold::9
#
# Mean CV Score of model KNeighborsRegressor():: 0.6290846489002692 at k-fold::10
#
# Mean CV Score of model KNeighborsRegressor():: 0.4442846352681558 at k-fold::11
#
#
# AdaBoostRegressor()
# -------------------------
#
#
# Mean CV Score of model AdaBoostRegressor():: 0.5922982802906948 at k-fold::7
#
# Mean CV Score of model AdaBoostRegressor():: 0.5291555174688063 at k-fold::8
#
# Mean CV Score of model AdaBoostRegressor():: 0.5791984846769429 at k-fold::9
#
# Mean CV Score of model AdaBoostRegressor():: 0.5817681349666474 at k-fold::10
#
# Mean CV Score of model AdaBoostRegressor():: 0.3593487587863717 at k-fold::11

# %%
CVmodel
# Out:
# {'LinearRegression()': [0.5658113799818976],
#  'DecisionTreeRegressor()': [0.6366544156002161],
#  'BaggingRegressor()': [0.7524276913880277],
#  'RandomForestRegressor()': [0.7725787083357123],
#  'KNeighborsRegressor()': [0.6290846489002692],
#  'AdaBoostRegressor()': [0.5922982802906948]}

# %% [markdown]
# Showing maximun cvScore for each model.

# %%
m=list(CVmodel.keys())

print("The least difference between the accuracy and CV score of each model is::\n")
for i in range(6):
    print(f"{m[i]}::{round(np.abs(CVmodel[m[i]][0]*100-maximum_acc[i]),2)}")
# Out:
# The least difference between the accuracy and CV score of each model is::
#
# LinearRegression()::16.84
# DecisionTreeRegressor()::28.14
# BaggingRegressor()::18.87
# RandomForestRegressor()::18.18
# KNeighborsRegressor()::24.41
# AdaBoostRegressor()::22.1

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_,Y,test_size=0.2,random_state=157)

#### Plotting regplot graph for Liear Regressor model
Linear.fit(X_train,Y_train)
Y_pred=Linear.predict(X_test)
sns.regplot(Y_test,Y_pred)
plt.xlabel("Actual Test Data")
plt.ylabel("Predicted Data")
plt.tight_layout()

# %% [markdown]
# As here we can see that the data points are scattered are not much closer to the best fit line.
# So, taking RandomForest model that has second least difference betwen the cv Score and r2-score.

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_,Y,test_size=0.2,random_state=178)

#### Plotting regplot graph for RandomForestRegressor model

RandomForest.fit(X_train,Y_train)
Y_pred=RandomForest.predict(X_test)
sns.regplot(Y_test,Y_pred)
plt.xlabel("Actual Test Data")
plt.ylabel("Predicted Data")
plt.tight_layout()

# %% [markdown]
# here for model RandomForestRegressor we get second the least value i.e. the difference between the accuracy and cvScore of this model is 18.07 and points are closer to the best line..
#
# Also the Random Forest residual is less than Linear model residual. Clearly seen from the graphs.

# %% [markdown]
# #### Regularization

# %%
lasso=Lasso()
parameters={"alpha":np.arange(0.0001,0.1,0.001),'normalize':[True,False],'max_iter':[1000,1500,2000]}
grid=GridSearchCV(lasso,parameters)
grid.fit(X_train,Y_train)
grid.best_params_
# Out:
# {'alpha': 0.09910000000000001, 'max_iter': 1000, 'normalize': True}

# %%
lasso=Lasso(alpha= 0.09910000000000001, max_iter= 1000, normalize=True)
lasso.fit(X_train,Y_train)
pred=lasso.predict(X_test)
r2_score(Y_test,pred)*100
# Out:
# 71.07109421722122

# %% [markdown]
# Here we can see that our model is not overfitted or underfitted as the r2 score Lasso model is 71 while the randomforest r2-score is 95.45

# %% [markdown]
# #### Hyper parameter Tuning

# %%
reg=RandomForestRegressor()
param={
    "n_estimators":[97,100,102],
    "min_samples_split":[2,4],
    "min_samples_leaf":[1,2,3],
    "max_depth":[21,26,28]
    
}
grd=GridSearchCV(reg,param_grid=param,cv=5)
grd.fit(X_train,Y_train)
print("Best Pramaeters:",grd.best_params_)

reg=grd.best_estimator_   #reinstantiating the best parameter to algo

reg.fit(X_train,Y_train)
ypred=reg.predict(X_test)

print(f"The accuracy is {round(r2_score(ypred,Y_test)*100,2)}% of model Random Forest.")


print("\nMEAN ABSOLUTE ERROR:",round(mean_absolute_error(ypred,Y_test),2))

print(f"\nMEAN SQUARED ERROR for the model:",round(mean_squared_error(ypred,Y_test),2))
    
print(f"\nROOT MEAN SQUARED ERROR for the model:",round(np.sqrt(mean_squared_error(ypred,Y_test)),2))
# Out:
# Best Pramaeters: {'max_depth': 26, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# The accuracy is 94.94% of model Random Forest.
#
# MEAN ABSOLUTE ERROR: 459.48
#
# MEAN SQUARED ERROR for the model: 585582.19
#
# ROOT MEAN SQUARED ERROR for the model: 765.23

# %%
import pickle
pickle.dump(RandomForest,open("flightPricePrediction.pickle","wb"))
